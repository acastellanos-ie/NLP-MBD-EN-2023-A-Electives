# %% [markdown]
# <a href="https://colab.research.google.com/github/acastellanos-ie/NLP-MBD-EN-2023-A-Electives/blob/main/tagging_parsing_practice/parsing_practice_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab Configuration
#
# **Execute this steps to configure the Google Colab environment in order to execute this notebook. It is not required if you are executing it locally and you have properly configured your local environment according to what explained in the Github Repository.**
#
# The first step is to clone the repository to have access to all the data and files

# %%
repository_name = "NLP-MBD-EN-2023-A-Electives"
repository_url = 'https://github.com/acastellanos-ie/' + repository_name

# %%
! git clone $repository_url

# %% [markdown]
# Install the requirements

# %%
! pip install -Uqqr $repository_name/requirements.txt

# %% [markdown]
# Now you have everything you need to execute the code in Colab

# %% [markdown]
# # Parsing Practice
#
# The purpose of this practical session is to gain more insight into using parsers and grammars and getting familiarized with the tools provided to this end by NLTK.
#
# **Our goals are to:**
#
# - Understand the process of parsing better by doing some examples by hand.
# - Gain insight into grammars by writing a grammar of our own.
# - Experiment with training a grammar from a corpus and evaluating it.
#
# **The practical session is organized in four sections:**
#
# - The warm-up, where you will use a given toy grammar to generate parse trees and get a chance to compare your intuition with the results provided by the NLTK parsers.
# - Then, you will need to design and test your own grammar, again, for a small example.
# - Next, you will automatically extract a grammar from a corpus of annotated sentences.
# - Finally, you are going to explore ways to improve automatically extracted grammars through error analysis.
#
# Before diving in, it would be helpful to have a look at how NLTK handles parsing. At the end of the Notebook, you will find a summary of the most useful commands. For more helpful explanations and examples, feel free to consult the [Chapter 8 of the NLTK Book](https://www.nltk.org/book/ch08.html), along with the chapter extras.

# %% [markdown]
# # Exercise 0
#
# Have a look at the texts and at the grammar below.

# %% [markdown]
# ### Input texts:
#
#     I saw an elephant
#     I saw an elephant in my pajamas
#
# ### Grammar:
#
#     S   -> NP VP     [1.0]
#     PP  -> P NP      [1.0]
#     NP  -> Det N     [0.4]
#     NP  -> Det N PP  [0.2]
#     VP  -> V NP      [0.5]
#     VP  -> VP PP     [0.5]
#
#     NP  -> 'I'        [0.4]
#     Det -> 'an'       [0.5]
#     Det -> 'my'       [0.5]
#     N   -> 'elephant' [0.5]
#     N   -> 'pajamas'  [0.5]
#     V   -> 'saw'      [1.0]
#     P   -> 'in'       [1.0]
#
#
#
# 1.- Load the previous grammar utilizing the `fromstring` method of the `PCFG` class.
#
# 2.- Using this grammar, try to parse the sample sentences with the NLTK `ChartParser` and then with the  NLTK `Viterbi` parser. This parser covers the two methodologies that we explained in class. The `ChartParser` does not care about probabilities; it just tries to find all the possible parses (trees) that fit the sentence. In contrast, Viterbi is a Dynamic Programming algorithm that tries to recursively find the best parse (tree) for the sentence based on the probabilities defined by the grammar.
#
# 3.- Examine the output of the parsers. Is there any difference?
#
# 4.- Using the NLTK GUI, draw the most probable parse trees found by the NLTK parsers and compare them.
#
# How are they different?
# Do they differ only in the names of the nonterminals' use, or is it a structural difference as well?
# Why do you think these differences occur?

# %% [markdown]
# # Solution 0

# %%
import nltk
from nltk.tree import *
from nltk.draw import tree

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Grammar creation
grammar = nltk.PCFG.fromstring("""
S -> NP VP 	[1.0]
PP -> P NP 	[1.0]
NP -> Det N 	[0.4]
NP -> Det N PP 	[0.2]
NP -> 'I' 	[0.4]
VP -> V NP 	[0.5]
VP -> VP PP 	[0.5]
Det -> 'an' 	[0.5]
Det -> 'my' 	[0.5]
N -> 'elephant' [0.5]
N ->  'pajamas' [0.5]
V -> 'saw' 	[1.0]
P -> 'in' 	[1.0]
""")

# Import example sentences to NLTK and tokenize them
str_sentence1 = "I saw an elephant"
str_sentence2 = "I saw an elephant in my pajamas"

print("Example sentences")
print(str_sentence1)
print(str_sentence2)
tokens1 = nltk.word_tokenize(str_sentence1)
tokens2 = nltk.word_tokenize(str_sentence2)

# Create the Chart and Viterbi parsers, with the input grammar
chart_parser = nltk.ChartParser(grammar)
viterbi_parser = nltk.ViterbiParser(grammar)

# Results for the Chart Parser
print("Parse trees obtained with the Chart parser")
print("Sentence 1")
for tree in chart_parser.parse(tokens1):
    print(tree)
    tree.pretty_print()

print("Sentence 2")
for tree in chart_parser.parse(tokens2):
    print(tree)
    tree.pretty_print()

# Results for the Viterbi Parser
print("Parse trees obtained with the Viterbi parser")
print("Sentence 1")
for tree in viterbi_parser.parse(tokens1):
    print(tree)
    tree.pretty_print()

print("Sentence 2")
for tree in viterbi_parser.parse(tokens2):
    print(tree)
    tree.pretty_print()
# Out:
# Example sentences
# I saw an elephant
# I saw an elephant in my pajamas
# Parse trees obtained with the Chart parser
# Sentence 1
# (S (NP I) (VP (V saw) (NP (Det an) (N elephant))))
#          S
#   _______|___
#  |           VP
#  |    _______|___
#  |   |           NP
#  |   |        ___|_____
#  NP  V      Det        N
#  |   |       |         |
#  I  saw      an     elephant
#
# Sentence 2
# (S
#   (NP I)
#   (VP
#     (VP (V saw) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
#      S
#   ___|_____________
#  |                 VP
#  |        _________|__________
#  |       VP                   PP
#  |    ___|___              ___|___
#  |   |       NP           |       NP
#  |   |    ___|_____       |    ___|_____
#  NP  V  Det        N      P  Det        N
#  |   |   |         |      |   |         |
#  I  saw  an     elephant  in  my     pajamas
#
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))
#      S
#   ___|_________
#  |             VP
#  |    _________|______
#  |   |                NP
#  |   |    ____________|___
#  |   |   |     |          PP
#  |   |   |     |       ___|___
#  |   |   |     |      |       NP
#  |   |   |     |      |    ___|_____
#  NP  V  Det    N      P  Det        N
#  |   |   |     |      |   |         |
#  I  saw  an elephant  in  my     pajamas
#
# Parse trees obtained with the Viterbi parser
# Sentence 1
# (S (NP I) (VP (V saw) (NP (Det an) (N elephant)))) (p=0.02)
#          S
#   _______|___
#  |           VP
#  |    _______|___
#  |   |           NP
#  |   |        ___|_____
#  NP  V      Det        N
#  |   |       |         |
#  I  saw      an     elephant
#
# Sentence 2
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP
#       (Det an)
#       (N elephant)
#       (PP (P in) (NP (Det my) (N pajamas)))))) (p=0.001)
#      S
#   ___|_________
#  |             VP
#  |    _________|______
#  |   |                NP
#  |   |    ____________|___
#  |   |   |     |          PP
#  |   |   |     |       ___|___
#  |   |   |     |      |       NP
#  |   |   |     |      |    ___|_____
#  NP  V  Det    N      P  Det        N
#  |   |   |     |      |   |         |
#  I  saw  an elephant  in  my     pajamas

# %% [markdown]
# We can notice that for the first sentence, the two the parsers agree on the result. This is due to the more simple structure of the sentence. For the second sentence, the Chart parser finds two parse trees, while the Viterbi parser outputs only one result. This occurs because the Viterbi parser only computes the most probable parse of the sentences, while the Chart parser is not concerned with the probabilities and it searches for all parse possibilities. In this case, we can notice that the most probable parse for the second sentence is the second parse produced by the Chart parser.

# %% [markdown]
# # Exercise 1

# %% [markdown]
# You are given  the following sentences:
#
#     Alice wondered with Bob in the empty city streets
#     Bob offered Alice an iguana for her birthday
#     Alice gave an inspiring speech at the conference on education
#
# 1. Design a non-probabilistic context-free grammar for parsing these sentences and then manually provide the parse tree(s) for these sentences. Here is a list of lexical rules and syntactic categories that you could use to devise the grammar:
#     Lexical rules:
#
#         V    -> 'wondered' | 'offered' | 'gave'
#         NP   -> 'Alice' | 'Bob'
#         N    -> 'city' | 'streets' | 'iguana' | 'birthday' | 'speech' | 'conference' | 'education'
#         Adj  -> 'empty' | 'inspiring'
#         Det  -> 'the' | 'an' | 'her'
#         Prep -> 'with' | 'in' | 'for' | 'at' | 'on'
#         Suggested syntactic categories (non-terminals):
#
#         S - Sentence
#         NP - Noun Phrase
#         VP - Verb Phrase
#         PNP - Prepositional Noun Phrase
# 2. With the grammar you designed in point (1.), parse the above sentences using NLTK’s Chart parser, described in Section 1.
# 3. Display and compare the parse trees obtained in points (1.) and (2.).

# %% [markdown]
# # Solution 1

# %% [markdown]
# **1. Design a non-probabilistic context-free grammar for parsing these sentences and then manually provide the parse tree(s) for these sentences. Here is a list of lexical rules and syntactic categories that you could use to devise the grammar:**

# %%
grammar = nltk.CFG.fromstring("""
S -> NP VP
VP -> V NP | VP NP PNP | VP PNP | V
PNP -> Prep NP | Prep N
NP -> Det N | Det N PNP | Det NP | Adj N | Adj NP | N N
V -> 'wondered' | 'offered' | 'gave'
NP -> 'Alice' | 'Bob'
N -> 'city' | 'streets' | 'iguana' | 'birthday' | 'speech' | 'conference' | 'education'
Adj -> 'empty' | 'inspiring'
Det -> 'the' | 'an' | 'her'
Prep -> 'with' | 'in' | 'for' | 'at' | 'on'
""")

# %% [markdown]
# **2. With the grammar you designed in point (1.), parse the above sentences using NLTK’s Chart parser, described in Section 1.**

# %%
str_sentence1 = "Alice wondered with Bob in the empty city streets"
str_sentence2 = "Bob offered Alice an iguana for her birthday"
str_sentence3 = "Alice gave an inspiring speech at the conference on education"
tokens1 = nltk.word_tokenize(str_sentence1)
tokens2 = nltk.word_tokenize(str_sentence2)
tokens3 = nltk.word_tokenize(str_sentence3)

# %% [markdown]
# **3. Display and compare the parse trees obtained in points (1.) and (2.).**

# %%
chart_parser = nltk.ChartParser(grammar)

print("Sentence 1")
for tree in chart_parser.parse(tokens1):
    print(tree)
print()

print("Sentence 2")
for tree in chart_parser.parse(tokens2):
    print(tree)
print()

print("Sentence 3")
for tree in chart_parser.parse(tokens3):
    print(tree)
print()
# Out:
# Sentence 1
# (S
#   (NP Alice)
#   (VP
#     (VP (VP (V wondered)) (PNP (Prep with) (NP Bob)))
#     (PNP
#       (Prep in)
#       (NP (Det the) (NP (Adj empty) (NP (N city) (N streets)))))))
#
# Sentence 2
# (S
#   (NP Bob)
#   (VP
#     (VP (V offered) (NP Alice))
#     (NP (Det an) (N iguana))
#     (PNP (Prep for) (NP (Det her) (N birthday)))))
#
# Sentence 3
# (S
#   (NP Alice)
#   (VP
#     (VP
#       (VP (V gave) (NP (Det an) (NP (Adj inspiring) (N speech))))
#       (PNP (Prep at) (NP (Det the) (N conference))))
#     (PNP (Prep on) (N education))))
# (S
#   (NP Alice)
#   (VP
#     (VP
#       (VP (V gave))
#       (NP (Det an) (NP (Adj inspiring) (N speech)))
#       (PNP (Prep at) (NP (Det the) (N conference))))
#     (PNP (Prep on) (N education))))
# (S
#   (NP Alice)
#   (VP
#     (VP (V gave) (NP (Det an) (NP (Adj inspiring) (N speech))))
#     (PNP
#       (Prep at)
#       (NP (Det the) (N conference) (PNP (Prep on) (N education))))))
# (S
#   (NP Alice)
#   (VP
#     (VP (V gave))
#     (NP (Det an) (NP (Adj inspiring) (N speech)))
#     (PNP
#       (Prep at)
#       (NP (Det the) (N conference) (PNP (Prep on) (N education))))))

# %% [markdown]
# # Exercise 2: Extracting a Grammar from a Corpus
#
# We have designed very simple grammars in the previous exercises. Even for these minimal examples, designing grammars are time-consuming and does not necessarily have the best results.
#
# We explore a different approach to creating grammars in this exercise: **automatic extraction from annotated texts**.
#
# We start from an annotated text: the `Treebank corpus` from the NLTK framework, which includes a small subset (5% fragment) of the `Penn Treebank Corpus`. It contains data from `Wall Street Journal` for 1650 sentences:
#
#     ( (S
#         (NP-SBJ
#           (NP (NNP Pierre) (NNP Vinken) )
#           (, ,)
#           (ADJP
#             (NP (CD 61) (NNS years) )
#             (JJ old) )
#           (, ,) )
#         (VP (MD will)
#           (VP (VB join)
#             (NP (DT the) (NN board) )
#             (PP-CLR (IN as)
#               (NP (DT a) (JJ nonexecutive) (NN director) ))
#             (NP-TMP (NNP Nov.) (CD 29) )))
#         (. .) ))
#
#
# The goal is to automatically extract the CFG from the treebank and then evaluate and improve the extracted grammar.

# %% [markdown]
# # Solution 2

# %% [markdown]
# **1. First, split the corpus into two parts : one for learning the grammar (training set) and one for evaluating it (test set). For the sake of saving time during this practical session, use 3% of the total number of sentences for the test set. Here is how you could make the split.**
#
#         dataset_size = len(treebank.parsed_sents())
#
#         ## here, we define the split percentage for the training set and the
#         ## learning set, in our case ~3% and ~97%
#
#         split_size = int(dataset_size * 0.97)
#         learning_set = treebank.parsed_sents()[:split_size]
#         test_set = treebank.parsed_sents()[split_size:]
#
#    Note that `test_set`  already contains the parses of the sentences. This is what we are going to compare against, in order to assess the quality of the extracted grammar. In addition, we need the raw (not parsed)  format of the sentences in the test set. These raw sentences will be parsed with the extracted grammar and then compared against the reference, stored in test_set.
#
#         # create a set containing the raw sentences
#         sents = treebank.sents()
#         raw_test_set = [ [ w for w in sents[i] ] for i in range(split_size, dataset_size) ]
#
# **Extract the grammar out of the learning corpus** At this point, it might be useful to have another look at the commands provided in the end of the document. Here is a suggestion on how to do it. Note that we still need the entire lexicon (i.e. rules of the type POS -> word) even though the syntactic rules are extracted from only a portion of the treebank. Assume that you have already separated the learning set from the test set and that the learning set is stored in the  learning_set  variable.
#
#         # This is where we will store all of the productions necessary to
#         # construct the PCFG.
#         tbank_productions = []
#
#         # For all of the (parsed) sentences in the learning set, extract the
#         # productions (i.e. extract the rules).
#         for sent in learning_set:
#             for production in sent.productions():
#                 tbank_productions.append(production)
#
#         # Now, we will add the lexical rules for the ENTIRE lexicon.
#         for word, tag in treebank.tagged_words():
#
#             # for each tagged word, we create a tree containing that
#             # lexical rule, in order to be able to add it to our
#             # production set tbank_productions.
#
#             t = Tree.fromstring("("+ tag + " " + word  +")")
#             for production in t.productions():
#                 tbank_productions.append(production)
#
#         # At this point, we have the syntactic rules extracted from the
#         # learning set and all of the lexical rules. We are ready to extract
#         # the PCFG.
#         tbank_grammar = nltk.grammar.induce_pcfg(Nonterminal('S'), tbank_productions)
#
# Try to have a look at the grammar. How many rules are there? Imagine you would have to correct it, for instance. You certainly will come to the conclusion that this is not feasible. Indeed, in such a framework (automated extraction) the grammars should not  be modified by hand (maybe not even read), but only the corpus has to be changed/corrected/extended.

# %% [markdown]
# Before executing the code you need to install the pre-trained parsing models

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# True

# %%
import nltk
from nltk.corpus import treebank
from nltk.grammar import Nonterminal
from nltk import Tree

print("Splitting the Data Set")
# The size of the learning set has to be chosen so that we avoid
# running out of memory when parsing (caused by a too large learned
# grammar). However, a too small size of the learning set, could lead
# to a grammar that is not useful (i.e. it cannot parse sentences
# other than in the learning set).

dataset_size = len(treebank.parsed_sents())
split_size = int(dataset_size*0.97)

print("Separating Learning Set")
print("Learning set size: " + str(split_size))
learning_set = treebank.parsed_sents()[:split_size]

print("Separating Test Set")
print("Test set size: " + str(dataset_size - split_size))
# This set already contains the parses of the sentences in the test
# set. It is what we are going to compare against, in order to assess
# the quality of the extracted grammar.
test_set = treebank.parsed_sents()[split_size:]

print("Set containing the raw sentences, to be parsed with the extracted grammar")
sents = treebank.sents()
raw_test_set = [ [ w for w in sents[i] ] for i in range(split_size, dataset_size) ]

print("Extract the syntactic (and part of the lexical) rules from the learning set")

tbank_productions = []
for sent in learning_set:
    for production in sent.productions():
        tbank_productions.append(production)

print(len(tbank_productions))
print("Extract the rest of the lexical rules from the lexicon")

for word, tag in treebank.tagged_words():
    t = Tree.fromstring("("+ tag + " " + word  +")")
    for production in t.productions():
        tbank_productions.append(production)

print(len(tbank_productions))

print("Creating grammar")
tbank_grammar = nltk.grammar.induce_pcfg(Nonterminal('S'), tbank_productions)

# Have a look at the grammar:
print(tbank_grammar)
# Out:
# Streaming output truncated to the last 5000 lines.
#     VP -> VBG PP-TMP S [7.10379e-05]
#     NP -> `` NP NN '' [4.34934e-05]
#     NN -> 'doctor' [7.73635e-05]
#     VP -> VBD ADJP-PRD PP-TMP PP , SBAR-ADV [7.10379e-05]
#     ADVP -> NP JJR [0.00326442]
#     VBN -> 'plunged' [0.000475172]
#     VB -> 'broaden' [0.000397062]
#     S -> ADVP , NP-SBJ-66 VP . [0.000119374]
#     RB -> 'Traditionally' [0.000359066]
#     NP-SBJ-66 -> DT NN [1.0]
#     -NONE- -> '*-66' [0.000154095]
#     NN -> 'entertainment' [7.73635e-05]
#     NNP -> 'Phillip' [0.000107788]
#     NNP -> 'Riese' [0.000323363]
#     NP -> DT NNP NNP JJ NN NN [4.34934e-05]
#     VP -> VP , CC `` VP [7.10379e-05]
#     NP -> NP JJ [4.34934e-05]
#     VP -> ADVP -LRB- MD VP [7.10379e-05]
#     VP -> VB -RRB- NP-PRD [7.10379e-05]
#     JJ -> 'car-care' [0.000173989]
#     VP -> VBG PRT NP-1 S-CLR [7.10379e-05]
#     NP-1 -> NP , NP , NP CC NP [0.0208333]
#     NN -> 'gasoline' [0.000154727]
#     VBP -> 'let' [0.000767165]
#     NP -> NN CC DT [4.34934e-05]
#     VBP -> 'realize' [0.000767165]
#     S-TPC-2 -> PP-TMP , ADVP , NP-SBJ VP [0.0119048]
#     VP -> VB NP PP-PUT PP-PRP [7.10379e-05]
#     NN -> 'down' [7.73635e-05]
#     NP -> NN CC NN NN NNS [4.34934e-05]
#     NN -> 'truth-in-lending' [7.73635e-05]
#     NNP -> 'GM' [0.000215575]
#     S-1 -> CC NP-SBJ VP . [0.0119048]
#     NNP -> 'GMAC' [0.000431151]
#     VP -> VBD NP PRN SBAR-PRP [7.10379e-05]
#     NP-SBJ -> DT NNP NNP JJ NN [0.000134971]
#     VP -> VP , CC ADVP VP [0.000213114]
#     NN -> 'billing' [7.73635e-05]
#     VP -> VBZ S , '' SBAR-ADV [7.10379e-05]
#     VBZ -> 'considers' [0.0014313]
#     S -> NP-SBJ `` NP-PRD [0.000119374]
#     NP-PRD -> ADJP JJ NNS [0.00367647]
#     JJ -> 'direct-mail' [0.000347977]
#     NNS -> 'marketers' [0.00016811]
#     S -> `` PP-MNR NP-SBJ-1 VP [0.000119374]
#     VB -> 'maximize' [0.000794123]
#     NN -> 'capability' [7.73635e-05]
#     S-TPC-1 -> PP , NP-SBJ VP [0.00460829]
#     NN -> 'nameplate' [0.000154727]
#     NP -> NNP NNP NN NNS [4.34934e-05]
#     S -> S-TPC-4 , NP-SBJ VP . [0.000238749]
#     S-TPC-4 -> SBAR-TMP , NP-SBJ VP [0.25]
#     VP -> VBD NP PP-LOC SBAR ADVP-TMP [7.10379e-05]
#     NN -> 'mailing' [7.73635e-05]
#     WHNP-2 -> WDT NNS [0.00714286]
#     VP -> VBD PRT UCP [7.10379e-05]
#     UCP -> ADVP CC PP [0.04]
#     NP -> DT NN CD [8.69868e-05]
#     NN -> 'top' [7.73635e-05]
#     NP-SBJ -> IN DT [0.000134971]
#     VBD -> 'screened' [0.000334672]
#     NN -> 'card-member' [7.73635e-05]
#     NP -> NP ADJP PP SBAR [8.69868e-05]
#     NNS -> 'incomes' [0.00016811]
#     WHNP-54 -> WP [0.5]
#     VP -> VBD RB `` VP [7.10379e-05]
#     VBN -> 'missed' [0.000475172]
#     S -> NP-SBJ-67 VP . [0.000119374]
#     NP-SBJ-67 -> NP PP [0.5]
#     NP -> DT CD CD [8.69868e-05]
#     CD -> '3.8' [0.00114695]
#     VBN -> 'preapproved' [0.000475172]
#     NP-SBJ-1 -> DT QP NNS [0.00100908]
#     NP -> NP VBN NN NNS [4.34934e-05]
#     WHNP-56 -> WDT [0.5]
#     VP -> VBP PP-CLR PP [7.10379e-05]
#     CD -> '6.9' [0.000573477]
#     NNP -> 'Visa' [0.000107788]
#     NNS -> 'cards' [0.00016811]
#     NN -> 'tie-in' [7.73635e-05]
#     NNP -> 'Express-Buick' [0.000107788]
#     NN -> 'link' [7.73635e-05]
#     S -> NP-SBJ VP : NP-1 . [0.000119374]
#     NP-SBJ -> NP PP-LOC NP [0.000134971]
#     VP -> VBG PP PP-CLR [7.10379e-05]
#     NP-1 -> NP : NP : CC NP [0.0208333]
#     NN -> 'establishment' [0.000154727]
#     WHNP-57 -> WDT [0.5]
#     JJ -> 'responsible' [0.000521966]
#     VBP -> 'accept' [0.000767165]
#     NP -> NP , CC RB NP [4.34934e-05]
#     NP -> NP CC PRN NP [4.34934e-05]
#     NNS -> 'accommodations' [0.00016811]
#     NNS -> 'tickets' [0.000336219]
#     NNS -> 'meals' [0.00016811]
#     NNS -> 'Destinations' [0.00016811]
#     NP-PRD -> NP : NP : NP : NP : NP : NP : NP : NP : NP : CC NP [0.00183824]
#     NNP -> 'Honolulu' [0.000107788]
#     NNP -> 'Orlando' [0.000107788]
#     NN -> 'buyer' [0.000464181]
#     VBZ -> 'chooses' [0.000954198]
#     VB -> 'fly' [0.000397062]
#     NN -> 'destination' [7.73635e-05]
#     VP -> VBZ NP SBAR-ADV [0.000142076]
#     NN -> 'companion' [7.73635e-05]
#     VBP -> 'fly' [0.000767165]
#     NNPS -> 'Airlines' [0.0208768]
#     NN -> 'lieu' [7.73635e-05]
#     NNS -> 'prizes' [0.000336219]
#     NN -> 'clock' [7.73635e-05]
#     NN -> 'stereo' [7.73635e-05]
#     NN -> 'recorder' [7.73635e-05]
#     NN -> 'Card' [7.73635e-05]
#     VBP -> 'receive' [0.00153433]
#     NN -> 'sweepstakes' [7.73635e-05]
#     VBP -> 'test-drive' [0.000767165]
#     NN -> 'calculator' [7.73635e-05]
#     NP-PRD -> NP JJ JJ NN [0.00183824]
#     JJ -> 'travel-related' [0.000173989]
#     JJ -> 'round-trip' [0.000173989]
#     NNP -> 'Trans' [0.000107788]
#     NNP -> 'Riviera' [0.000215575]
#     NN -> 'luxury' [0.000154727]
#     VB -> 'exceed' [0.00119119]
#     S -> ADJP-PRD NP-SBJ [0.000119374]
#     NP -> NN NN NNS CC NNS NNS [4.34934e-05]
#     NN -> 'interest-rate' [0.00023209]
#     NN -> 'borough' [7.73635e-05]
#     NN -> 'cancellation' [0.000154727]
#     NNP -> 'Borough' [0.000107788]
#     NNP -> 'Hammersmith' [0.000538938]
#     NNP -> 'Fulham' [0.000215575]
#     NP-SBJ-1 -> QP NNP CC JJ NNS [0.00100908]
#     RB -> 'As' [0.000359066]
#     SINV -> MD NP-SBJ-2 VP [0.00515464]
#     VBN -> 'upheld' [0.000475172]
#     S -> NP-SBJ-68 VP . [0.000119374]
#     NP-SBJ-68 -> DT NN [0.5]
#     S -> PP , NP-SBJ-1 ADVP-MNR VP . [0.000119374]
#     JJ -> 'gilt' [0.000173989]
#     VP -> VBD NP-ADV NP-TMP PP-TMP [7.10379e-05]
#     VBG -> 'recovering' [0.000696379]
#     NNS -> 'Gilts' [0.00016811]
#     VP -> VBD ADVP-MNR ADVP [7.10379e-05]
#     VP -> VBD NP S-ADV [7.10379e-05]
#     VBD -> 'retraced' [0.000334672]
#     WHNP-61 -> WDT [0.5]
#     NP -> IN CD NNS [4.34934e-05]
#     CD -> '600' [0.000860215]
#     NP -> NP -LRB- NP -RRB- [4.34934e-05]
#     JJ -> 'soured' [0.000173989]
#     VBN -> 'accounted' [0.000475172]
#     NN -> 'sterling' [7.73635e-05]
#     NP-SBJ -> CD NNS [0.000134971]
#     VBP -> 'engage' [0.000767165]
#     VBG -> 'betting' [0.000696379]
#     VBD -> 'obligated' [0.000334672]
#     VP -> NNS NP PP-CLR [7.10379e-05]
#     NNS -> 'swaps' [0.000336219]
#     VP -> VBD PP-TMP-CLR PP [7.10379e-05]
#     NNP -> 'Hazell' [0.000107788]
#     NN -> 'auditor' [7.73635e-05]
#     NNS -> 'councils' [0.000672438]
#     VBN -> 'vested' [0.000475172]
#     VB -> 'engage' [0.000397062]
#     JJ -> 'capital-markets' [0.000347977]
#     VBD -> 'backed' [0.000334672]
#     NN -> 'audit' [7.73635e-05]
#     VP -> VBD PP-PRD NP [7.10379e-05]
#     PP-PRD -> IN ADVP [0.0119048]
#     VBG -> 'engaging' [0.000696379]
#     VP -> VB ADJP-PRD PP [0.000213114]
#     JJ -> 'persuasive' [0.000173989]
#     NN -> 'solicitor' [7.73635e-05]
#     RB -> 'Already' [0.000359066]
#     NP-SBJ-1 -> CD JJ NNS [0.00100908]
#     NNP -> 'Barclays' [0.000107788]
#     NNP -> 'Midland' [0.000107788]
#     NNP -> 'Citibank' [0.000107788]
#     VBP -> 'exhaust' [0.000767165]
#     NNS -> 'avenues' [0.00016811]
#     NN -> 'illegality' [7.73635e-05]
#     VB -> 'recover' [0.000794123]
#     VP -> VBD NP PP-CLR ADVP-LOC [7.10379e-05]
#     VP -> VB PP-TMP S-PRP-CLR [7.10379e-05]
#     NNS -> 'arrangements' [0.00016811]
#     VP -> VB ADVP ADVP-TMP [0.000142076]
#     NN -> 'aftermath' [0.000154727]
#     JJ -> 'gut-wrenching' [0.000173989]
#     JJ -> '190-point' [0.000173989]
#     NP-SBJ -> NP NP PP-LOC [0.000134971]
#     NP -> NNP , NNP CC NNP POS [4.34934e-05]
#     NNP -> 'Kidder' [0.000431151]
#     NNP -> 'Peabody' [0.000323363]
#     CD -> '1,400' [0.000286738]
#     NNS -> 'stockbrokers' [0.000504329]
#     NP -> DT NN CC JJ NN [4.34934e-05]
#     JJ -> 'letter-writing' [0.000173989]
#     VBG -> 'quashing' [0.000696379]
#     NN -> 'wrath' [7.73635e-05]
#     NP -> NP , NP . [0.00013048]
#     S -> PP-TMP , NP-SBJ-69 VP . [0.000119374]
#     NN -> 'minicrash' [7.73635e-05]
#     NP-SBJ-69 -> NNP NNP [0.5]
#     VBN -> 'shaken' [0.000475172]
#     NN -> 'resentment' [7.73635e-05]
#     JJ -> 'lightning-fast' [0.000173989]
#     NNS -> 'baskets' [0.000336219]
#     VBG -> 'reeling' [0.000696379]
#     VBN -> 'heated' [0.000475172]
#     PP-PRD -> IN SBAR-NOM [0.0119048]
#     VB -> 'control' [0.000397062]
#     VB -> 'reap' [0.000397062]
#     S -> NP-SBJ-1 , PP , VP . [0.000238749]
#     NNS -> 'academics' [0.00016811]
#     WHNP-64 -> WP [0.5]
#     VP -> VBN NP PP-LOC , S-ADV [7.10379e-05]
#     S-ADV -> NP-SBJ-2 ADVP VP [0.00465116]
#     VBN -> 'labeled' [0.000950344]
#     NP -> DT NN VBG NN [4.34934e-05]
#     NN -> 'evil' [7.73635e-05]
#     VP -> VBD RB PRN VP [7.10379e-05]
#     VBN -> 'exacerbated' [0.000475172]
#     SINV -> PP-LOC-CLR-TPC-1 VP NP-SBJ . [0.00515464]
#     PP-LOC-CLR-TPC-1 -> IN NP [1.0]
#     VP -> VBP PP-LOC-CLR [7.10379e-05]
#     PP-LOC-CLR -> -NONE- [0.0338983]
#     NP-SBJ -> NP PP PP-LOC PRN VP [0.000134971]
#     NN -> 'ascendency' [7.73635e-05]
#     NNP -> 'Guard' [0.00107788]
#     VBG -> 'consisting' [0.000696379]
#     NNS -> 'wizards' [0.00016811]
#     NN -> 'immense' [7.73635e-05]
#     NNS -> 'pools' [0.00016811]
#     NP -> DT JJ NNP NNS NNS [4.34934e-05]
#     JJ -> 'fast-growing' [0.000347977]
#     SINV -> VP-TPC-1 VP NP-SBJ . [0.00515464]
#     VP-TPC-1 -> VBG NP [0.5]
#     VBG -> 'Defending' [0.000696379]
#     NNS -> 'ramparts' [0.00016811]
#     NP-SBJ -> NP : NP [0.000269942]
#     NP -> DT JJ , JJ NN NNS [4.34934e-05]
#     JJ -> 'stock-picking' [0.000173989]
#     NNS -> 'tens' [0.00016811]
#     NP -> NP VBN NNS [4.34934e-05]
#     NP -> DT NNP NNP NNP NNP POS [8.69868e-05]
#     NP -> NP , VP , SBAR [4.34934e-05]
#     JJ -> 'clannish' [0.000173989]
#     SBAR -> WHNP-65 S [0.00043956]
#     S-ADV -> NP-SBJ-3 ADVP VP [0.00930233]
#     RB -> 'successfully' [0.000359066]
#     VBG -> 'mobilizing' [0.000696379]
#     VB -> 'bludgeon' [0.000397062]
#     NNS -> 'tormentors' [0.00016811]
#     NN -> 'layer' [7.73635e-05]
#     ADJP -> RB VBG [0.00301205]
#     NP-SBJ-70 -> DT NNP NNP [0.5]
#     VP -> VBN NP-TMP S [7.10379e-05]
#     NP-LGS -> NNS SBAR [0.00438596]
#     JJ -> 'gigantic' [0.000173989]
#     NN -> 'crapshoot' [7.73635e-05]
#     NP-SBJ-1 -> RB PDT DT JJ NN NN NNS [0.00100908]
#     NP-SBJ-1 -> NP , PP , [0.00100908]
#     NP -> JJ NNP NNP CC NNP [4.34934e-05]
#     VBP -> 'refuse' [0.00153433]
#     NNS -> 'practitioners' [0.000336219]
#     VP -> VBN ADJP-PRD , SBAR-PRP [7.10379e-05]
#     JJ -> 'broad-based' [0.000173989]
#     NN -> 'livelihood' [7.73635e-05]
#     RB -> 'Some' [0.000718133]
#     NP -> JJ NN NN NNP CC NNP [4.34934e-05]
#     NNP -> 'Neuberger' [0.000646726]
#     NNP -> 'Berman' [0.000215575]
#     NN -> 'racket' [0.000154727]
#     S -> NP-SBJ-1 , PP-LOC , VP . [0.000119374]
#     NP-SBJ-1 -> NNP NNP NN NNS [0.00100908]
#     NN -> 'palace' [7.73635e-05]
#     NN -> 'revolt' [7.73635e-05]
#     VB -> 'telephone' [0.000397062]
#     WHNP-2 -> WP$ NN [0.0142857]
#     S -> NP-SBJ-71 VP [0.000119374]
#     NP-SBJ-71 -> -NONE- [0.5]
#     NNP -> 'Wohlstetter' [0.000107788]
#     NNP -> 'Contel' [0.000323363]
#     VBG -> 'rallying' [0.000696379]
#     JJ -> 'anti-program' [0.000173989]
#     JJ -> 'countless' [0.000173989]
#     VP -> VBD ADVP , PP : S [7.10379e-05]
#     RB -> 'universally' [0.000359066]
#     VP -> VB RB ADVP VP [7.10379e-05]
#     VB -> 'Do' [0.000397062]
#     VB -> 'Kill' [0.000397062]
#     VP -> VBZ RB ADJP-PRD , ADVP [7.10379e-05]
#     VP -> VB NP S-MNR PP-TMP [7.10379e-05]
#     ADJP -> RB [0.00451807]
#     NP-SBJ -> PRP$ JJ NNS CC NN NNS [0.000134971]
#     NP-SBJ -> NN NN NN NNS [0.000134971]
#     NP-SBJ -> NP PP S-2 [0.000269942]
#     JJ -> 'consistent' [0.000173989]
#     VBN -> 'wedded' [0.000475172]
#     VP -> VB ADVP-MNR PP-DIR [7.10379e-05]
#     PP-DIR -> IN CC IN NP [0.0025974]
#     S -> SBAR-ADV , ADVP-TMP NP-SBJ VP . [0.000119374]
#     SBAR-ADV -> WHNP-67 S [0.00346021]
#     WHNP-67 -> WP [0.5]
#     NP-PRD -> JJR [0.00183824]
#     ADVP-TMP -> NP-ADV PRN [0.00163399]
#     NP-SBJ -> JJ NNP NNP NNS [0.000134971]
#     PRN -> : PP-TMP : [0.00338983]
#     VBD -> 'waited' [0.000334672]
#     NP-TMP-CLR -> DT JJ NNS [0.0434783]
#     VP -> VBD ADVP-DIR PP-DIR [7.10379e-05]
#     VBD -> 'sneaked' [0.000334672]
#     NP -> RB DT NNS [4.34934e-05]
#     VBG -> 'conceding' [0.000696379]
#     NP -> NP ADJP NN NNS [4.34934e-05]
#     ADJP -> RBS VBN [0.00150602]
#     NP -> DT JJ NNS POS [8.69868e-05]
#     NP -> NNP NNP NNP NNP NNP NNP NNP [4.34934e-05]
#     VP -> VBD PP-LOC-CLR SBAR [7.10379e-05]
#     VP -> ADVP VBN PP-CLR [7.10379e-05]
#     VP -> `` VBN PP-DIR '' SBAR-ADV [7.10379e-05]
#     VBN -> 'headed' [0.000475172]
#     VBN -> 'curbed' [0.000475172]
#     SBAR-NOM -> WHNP-3 S [0.0377358]
#     ADJP -> JJR PP [0.00150602]
#     NN -> 'casino' [0.000154727]
#     VP -> VBN PP-CLR PP-LOC , S-ADV [7.10379e-05]
#     JJ -> 'civil' [0.000173989]
#     NNS -> 'contradictions' [0.00016811]
#     VBG -> 'pitting' [0.000696379]
#     VBP -> 'battle' [0.000767165]
#     NP -> PRP$ JJ NN POS [4.34934e-05]
#     NNS -> 'floors' [0.00016811]
#     NNS -> 'Corporations' [0.000336219]
#     VBP -> 'denounce' [0.000767165]
#     VP -> VBZ PP-TMP VP [0.000142076]
#     JJ -> 'premier' [0.000173989]
#     NP-SBJ -> PRP$ VBN CD NN NNS NNS [0.000134971]
#     VBN -> 'entrenched' [0.000475172]
#     ADVP-MNR -> NN CC NN [0.00408163]
#     NN -> 'tooth' [7.73635e-05]
#     NN -> 'nail' [7.73635e-05]
#     S -> CC NP-SBJ-1 PRN ADVP-TMP VP . [0.000119374]
#     NN -> 'basket' [0.000541544]
#     VB -> 'facilitate' [0.000397062]
#     VP -> VB ADVP-DIR PP-DIR [0.000142076]
#     NP -> NP , '' PP [4.34934e-05]
#     RB -> 'Again' [0.000359066]
#     NN -> 'program-trading' [0.00023209]
#     NN -> 'theme' [7.73635e-05]
#     JJ -> 'greedy' [0.000173989]
#     NNS -> 'manipulators' [0.00016811]
#     NN -> 'shambles' [7.73635e-05]
#     NN -> 'free-enterprise' [7.73635e-05]
#     VP -> VBG NP PP-CLR , PP [7.10379e-05]
#     NN -> 'gambling' [7.73635e-05]
#     NN -> 'den' [7.73635e-05]
#     NNS -> 'odds' [0.00016811]
#     VBN -> 'stacked' [0.000475172]
#     S-TPC-2 -> S : S [0.0119048]
#     VP -> VBN PP-DIR S-PRP [7.10379e-05]
#     NNP -> 'Off-Track' [0.000107788]
#     NNP -> 'Betting' [0.000107788]
#     NNP -> 'Brean' [0.000215575]
#     NP -> NNP NNP , NNP NNPS [4.34934e-05]
#     VBP -> 'portray' [0.000767165]
#     JJ -> 'old-fashioned' [0.000173989]
#     NNS -> 'pickers' [0.000672438]
#     NNS -> 'Neanderthals' [0.00016811]
#     S-TPC-3 -> S , CC S [0.0909091]
#     NNS -> 'witches' [0.00016811]
#     VP -> VBP NP S-CLR [0.000213114]
#     NN -> 'boogieman' [7.73635e-05]
#     NNP -> 'Advanced' [0.000215575]
#     NN -> 'unknown' [7.73635e-05]
#     VB -> 'beg' [0.000397062]
#     JJ -> 'computer-assisted' [0.000347977]
#     S -> PP , NP-SBJ-1 ADVP VP . [0.000119374]
#     JJ -> 'momentary' [0.000173989]
#     PRN -> : PP , NP : [0.00338983]
#     PRN -> : PP NP [0.00338983]
#     NP -> DT NNP NNS NNS [4.34934e-05]
#     NN -> 'divergence' [7.73635e-05]
#     SBAR-NOM-PRD -> WHNP-69 S [0.333333]
#     NP-SBJ -> NN NN NNS [0.00107977]
#     VBZ -> 'occurs' [0.000954198]
#     VP -> VBP NP PP-MNR S-2 [7.10379e-05]
#     VBP -> 'place' [0.000767165]
#     VBP -> 'constitute' [0.000767165]
#     NP -> NP CD NN NN [4.34934e-05]
#     NP -> DT NNP CC NNP POS [4.34934e-05]
#     PP-LOC -> IN SBAR-NOM [0.000867303]
#     SBAR-NOM -> WHNP-4 S [0.0188679]
#     WHNP-4 -> WDT NN [0.111111]
#     WDT -> 'whichever' [0.00228833]
#     JJR -> 'cheaper' [0.0134228]
#     VP -> VBP PRT NP PP-CLR [7.10379e-05]
#     VBP -> 'lock' [0.000767165]
#     VP -> VBP PP-TMP-CLR [0.000142076]
#     VBP -> 'occur' [0.000767165]
#     NNS -> 'seconds' [0.00016811]
#     JJ -> 'razor-thin' [0.000173989]
#     S -> NP-SBJ ADJP-PRD PP [0.000119374]
#     VB -> 'seize' [0.000794123]
#     NN -> 'speed' [0.000154727]
#     NNS -> 'movements' [0.000336219]
#     VP -> VBP SBAR-NOM-PRD [7.10379e-05]
#     SBAR-NOM-PRD -> WHNP-4 S [0.333333]
#     NP-SBJ-3 -> NN NN NNS [0.00980392]
#     VBP -> 'profess' [0.000767165]
#     VB -> 'despise' [0.000397062]
#     S-TPC-3 -> SBAR-ADV , NP-SBJ VP [0.0454545]
#     VP -> VBZ ADJP-PRD : NP-1 [7.10379e-05]
#     VBN -> 'frightened' [0.000475172]
#     NP-1 -> NP : NP [0.0208333]
#     NN -> 'lotter' [7.73635e-05]
#     NNP -> 'Zicklin' [0.000107788]
#     NP-SBJ -> JJ NNS CC NNS [0.000134971]
#     S-TPC-1 -> `` NP-SBJ VP [0.00460829]
#     NN -> 'iota' [7.73635e-05]
#     NP-SBJ -> NP , NP , NP [0.000269942]
#     NNP -> 'Vanderbilt' [0.000215575]
#     NNP -> 'Hans' [0.000107788]
#     NNP -> 'Stoll' [0.000215575]
#     NN -> 'Volatility' [0.000154727]
#     S -> NP-SBJ-72 VP . [0.000119374]
#     NP-SBJ-72 -> DT NNP CD NN [0.5]
#     PP -> RB PP , CC PP [0.000200642]
#     NN -> 'unraveling' [7.73635e-05]
#     CD -> '6.79' [0.000573477]
#     NNP -> 'UAL' [0.0017246]
#     S-ADV -> NP-SBJ-3 ADJP-PRD [0.00465116]
#     JJ -> 'Unable' [0.000173989]
#     VB -> 'unload' [0.000397062]
#     NP-SBJ-2 -> NP , CC NP , [0.00315457]
#     JJ -> 'takeover-stock' [0.000173989]
#     NNS -> 'arbitragers' [0.00016811]
#     JJ -> 'blue-chip' [0.000521966]
#     S -> NP-SBJ ADVP-MNR VP [0.000477498]
#     VP -> VBD PRT [0.000142076]
#     VBD -> 'kicked' [0.000334672]
#     VBD -> 'halted' [0.000334672]
#     NNP -> 'Del' [0.000107788]
#     NNP -> 'Signore' [0.000107788]
#     NP -> NNPS NNP NNP NNP [4.34934e-05]
#     NNPS -> 'Travelers' [0.0167015]
#     VP -> VBG `` NP PP-CLR [7.10379e-05]
#     NP-SBJ -> DT -LRB- NN NN -RRB- NN [0.000134971]
#     NN -> 'speculator' [7.73635e-05]
#     S-3 -> S , '' PRN , CC S . '' [0.166667]
#     NNS -> 'arbs' [0.00016811]
#     JJ -> 'overleveraged' [0.000173989]
#     VP -> VBP SBAR ADVP-TMP [7.10379e-05]
#     VP -> VBP ADVP-CLR [7.10379e-05]
#     VBP -> 'fall' [0.0023015]
#     RB -> 'apart' [0.000359066]
#     NNS -> 'traditionalists' [0.00016811]
#     VP -> VBG PRT PP-CLR PP-CLR PP-TMP [7.10379e-05]
#     NNS -> 'bundles' [0.00016811]
#     NP -> `` NP , '' SBAR-ADV [4.34934e-05]
#     RB -> 'derisively' [0.000359066]
#     NNS -> 'jockeys' [0.00016811]
#     JJ -> 'Traditional' [0.000173989]
#     NP -> NP TO NP [4.34934e-05]
#     VBP -> 'manage' [0.000767165]
#     S -> CC NP-SBJ-2 ADVP VP [0.000119374]
#     NP-SBJ-2 -> JJ JJ NNS [0.00315457]
#     VP -> VP , ADVP VP , NP-1 [7.10379e-05]
#     VP -> VB PRT PP [7.10379e-05]
#     ADVP -> RB JJR [0.00326442]
#     NNS -> 'benchmarks' [0.00016811]
#     JJ -> 'old-style' [0.000173989]
#     VB -> 'juggle' [0.000397062]
#     VBP -> 'mirror' [0.000767165]
#     NNS -> 'indexers' [0.000336219]
#     NNS -> 'pennies' [0.00016811]
#     S -> NP-TMP , NP-SBJ-73 VP . [0.000119374]
#     NP-SBJ-73 -> NP , CC NP , [0.5]
#     JJ -> 'pension-fund' [0.000173989]
#     VBN -> 'automated' [0.000475172]
#     VBZ -> 'threatens' [0.000477099]
#     NNS -> 'dinosaurs' [0.00016811]
#     NP -> DT CD NNP NNP JJ NNS [4.34934e-05]
#     JJ -> 'stock-specialist' [0.000173989]
#     NP-SBJ -> DT ADJP NN NNS [0.000134971]
#     VP -> VBN NP PP , PP [0.000213114]
#     VBN -> 'earned' [0.000475172]
#     NN -> 'virtue' [0.000154727]
#     NN -> 'monopoly' [7.73635e-05]
#     NN -> 'knell' [7.73635e-05]
#     S -> NP-SBJ , PP , VP [0.000119374]
#     NP-PRD -> NP CC ADVP-TMP NP [0.00183824]
#     RB -> 'nonetheless' [0.000359066]
#     VP -> VBG PRN S [7.10379e-05]
#     VBG -> 'striving' [0.000696379]
#     VP -> VBP NP ADVP [7.10379e-05]
#     VBP -> 'dislike' [0.000767165]
#     VP -> VB NP-3 PP [7.10379e-05]
#     NP-3 -> NP CC NP [0.0833333]
#     SINV -> S-TPC-3 , VP NP-SBJ . [0.0154639]
#     S-TPC-3 -> `` SBAR-TMP , NP-SBJ VP [0.0454545]
#     VBP -> 'hit' [0.000767165]
#     NP-SBJ-2 -> DT NN NNS [0.00315457]
#     NNS -> 'printers' [0.00016811]
#     VP -> VB '' PP-LOC [7.10379e-05]
#     NP-SBJ-74 -> DT NN [0.5]
#     VP -> VBN NP ADVP '' PP [7.10379e-05]
#     ADJP -> RBR JJ PP [0.00150602]
#     VBN -> 'spooked' [0.000475172]
#     NNS -> 'swings' [0.000840548]
#     JJ -> 'Small' [0.000347977]
#     ADJP-PRD -> RB JJ SBAR [0.00341297]
#     RB -> 'absolutely' [0.000718133]
#     JJ -> 'dismayed' [0.000173989]
#     VBG -> 'stacking' [0.000696379]
#     NN -> 'deck' [7.73635e-05]
#     JJ -> 'wide' [0.000695955]
#     VBG -> 'scaring' [0.000696379]
#     NNP -> 'Raymond' [0.000107788]
#     NP -> JJ NN NNP NNP NNP [4.34934e-05]
#     NN -> 'broker' [0.000154727]
#     NNP -> 'Legg' [0.000215575]
#     NP-SBJ -> NP NN CC NN [0.000134971]
#     NNS -> 'Stockbrokers' [0.00016811]
#     CD -> '71,309' [0.000286738]
#     JJ -> 'Corporate' [0.000347977]
#     VBP -> 'resent' [0.000767165]
#     S -> NP-SBJ-75 VP [0.000119374]
#     NP-SBJ-75 -> NP NN [1.0]
#     VBN -> 'transformed' [0.000475172]
#     -NONE- -> '*-75' [0.000154095]
#     JJ -> 'nameless' [0.000173989]
#     S-TPC-3 -> NP-SBJ ADVP-TMP VP [0.0454545]
#     NN -> 'Index' [0.000154727]
#     VBZ -> 'complains' [0.000954198]
#     NNP -> 'Sigler' [0.000215575]
#     NNP -> 'Champion' [0.000215575]
#     SQ -> `` VBP NP-SBJ VP . [0.0294118]
#     NNS -> 'sweatshirts' [0.00016811]
#     NNS -> 'sparkplugs' [0.00016811]
#     S -> S-SBJ '' VP . [0.000119374]
#     S-SBJ -> INTJ , NP-SBJ VP , [0.333333]
#     UH -> 'Oh' [0.333333]
#     NP -> DT NN CD NN [4.34934e-05]
#     NP -> NP JJ JJ NN NN [4.34934e-05]
#     NNS -> 'bloods' [0.00016811]
#     NP -> NP , NP , NP , NP CC NP [4.34934e-05]
#     NNPS -> 'Brothers' [0.0125261]
#     SINV -> CC ADVP-TMP VP NP-SBJ . [0.00515464]
#     NN -> 'publicity' [7.73635e-05]
#     VBN -> 'orchestrated' [0.000475172]
#     NP-LGS -> DT NNP NNP [0.00438596]
#     NN -> 'strategy' [0.000618908]
#     VB -> 'hunker' [0.000397062]
#     JJ -> 'lynch-mob' [0.000173989]
#     NN -> 'psychology' [0.00023209]
#     NN -> 'cow' [7.73635e-05]
#     VBN -> 'gored' [0.000475172]
#     VBN -> 'proven' [0.000475172]
#     RB -> 'Too' [0.000718133]
#     VP -> VBZ PP-PRD SBAR-1 [7.10379e-05]
#     S -> PP , S , CC S . [0.000119374]
#     JJ -> 'fastest-growing' [0.000173989]
#     NP-SBJ -> NN NNS NN [0.000134971]
#     VBN -> 'minted' [0.000475172]
#     NNS -> 'millionaires' [0.00016811]
#     NP -> PRP$ CD CC CD [4.34934e-05]
#     CD -> '20s' [0.000286738]
#     CD -> '30s' [0.000286738]
#     S -> ADVP-TMP , PP-TMP , NP-SBJ VP . [0.000119374]
#     VBZ -> 'trades' [0.000954198]
#     S -> ADVP-TMP NP-SBJ-76 VP . [0.000119374]
#     NP-SBJ-76 -> DT NN [0.5]
#     NNS -> 'anti-programmers' [0.000336219]
#     NN -> 'thunder' [7.73635e-05]
#     NP-SBJ -> NP `` NN S [0.000134971]
#     NP -> NN NNS POS [4.34934e-05]
#     VB -> 'create' [0.00238237]
#     S -> `` NP-SBJ-1 VP : [0.000119374]
#     VB -> 'Sit' [0.000397062]
#     S -> NP-SBJ VP , [0.000119374]
#     VB -> 'panic' [0.000397062]
#     S -> NP-SBJ VP . '' '' [0.000119374]
#     NN -> 'jeopardy' [7.73635e-05]
#     JJ -> 'unlikely' [0.000173989]
#     RB -> 'anytime' [0.000718133]
#     VP -> VB NP ADVP|PRT PP-PUT [7.10379e-05]
#     NN -> 'genie' [7.73635e-05]
#     ADVP|PRT -> RB [1.0]
#     VP -> VBP ADVP-TMP S-PRP [7.10379e-05]
#     ADVP-TMP -> NN [0.00163399]
#     S -> NP-SBJ-77 VP [0.000119374]
#     NP-SBJ-77 -> DT JJ NN [1.0]
#     -NONE- -> '*-77' [0.000154095]
#     S -> S , CC S , CC S . '' [0.000119374]
#     ADJP-PRD -> RB S-CLR [0.00341297]
#     S -> NP-SBJ-3 ADVP VP [0.000119374]
#     VB -> 'understand' [0.000794123]
#     JJ -> 'Short' [0.000173989]
#     JJ -> 'middle-ground' [0.000173989]
#     SBAR -> SBAR SBAR [0.00043956]
#     VBP -> 'enjoy' [0.000767165]
#     VP -> VBP RB NP [7.10379e-05]
#     NN -> 'margin' [0.000464181]
#     NN -> 'good-faith' [7.73635e-05]
#     NP -> IN DT JJ NN [4.34934e-05]
#     NP -> NN NNS NNS [8.69868e-05]
#     VP -> VBP ADJP-PRD PRN S-ADV [7.10379e-05]
#     ADJP-PRD -> RB JJR [0.00853242]
#     PRN -> : NP PP : [0.00338983]
#     NP -> RB CD NN [0.000173974]
#     RB -> 'potentially' [0.000359066]
#     JJ -> 'speculative' [0.000695955]
#     NNS -> 'Futures' [0.000420274]
#     VBP -> 'respond' [0.000767165]
#     VBP -> 'help' [0.00153433]
#     VB -> 'chase' [0.000397062]
#     WHNP-72 -> WP [0.5]
#     VP -> VB CC VB [7.10379e-05]
#     NN -> 'uptick' [0.000309454]
#     NNP -> 'Crash' [0.000107788]
#     VBZ -> 'protects' [0.000477099]
#     VP -> VBG ADVP-MNR VP [0.000142076]
#     RB -> 'relentlessly' [0.000359066]
#     VP -> VBN NP ADVP-DIR PP [7.10379e-05]
#     VBN -> 'beaten' [0.000950344]
#     RB -> 'downward' [0.000359066]
#     NP-LGS -> NP , ADVP NP [0.00438596]
#     VB -> 'profit' [0.00119119]
#     NNS -> 'sellers' [0.000336219]
#     VP -> VBG PP-MNR ADVP-TMP [7.10379e-05]
#     VP -> VBD SBAR-NOM , S-PRP [7.10379e-05]
#     SBAR-NOM -> WHNP-73 S [0.0188679]
#     WHNP-73 -> WP [0.5]
#     S -> NP-SBJ ADJP-PRD S-1 [0.000119374]
#     NP -> DT NN CC NNS NNS [4.34934e-05]
#     VB -> 'destroy' [0.000397062]
#     NN -> 'efficiency' [7.73635e-05]
#     NP -> DT NNS CC NN NNS [4.34934e-05]
#     NP-HLN -> NNPS NNP [0.027027]
#     NNPS -> 'Fundamentalists' [0.00417537]
#     NNP -> 'Jihad' [0.000215575]
#     NN -> 'stock-price' [7.73635e-05]
#     JJ -> 'band-wagon' [0.000173989]
#     VBZ -> 'picks' [0.000477099]
#     NN -> 'impetus' [7.73635e-05]
#     S -> SBAR-ADV NP-SBJ VP . [0.000238749]
#     VBN -> 'practiced' [0.000475172]
#     NP-SBJ -> NP PP-LOC , VP , [0.000134971]
#     NNS -> 'locations' [0.00016811]
#     NNS -> 'widgets' [0.000336219]
#     VP -> VB NP PP-TMP PP-CLR [7.10379e-05]
#     S -> PP-LOC , S , CC S . [0.000238749]
#     NN -> 'widget' [0.000541544]
#     NP-PRD -> DT NNP CD [0.00183824]
#     RB -> 'constantly' [0.0010772]
#     JJ -> 'index-arbitrage' [0.000695955]
#     WHNP-75 -> WP [0.5]
#     NP -> DT JJR NNP CD NN [4.34934e-05]
#     NP-SBJ-78 -> NP VP [0.5]
#     VBG -> 'performing' [0.00139276]
#     VB -> 'match' [0.000794123]
#     VP -> ADVP VBN PP-TMP [7.10379e-05]
#     S -> -LRB- S , CC S . -RRB- [0.000119374]
#     NP-SBJ-1 -> JJ PRN JJ NNS [0.00100908]
#     JJ -> 'Few' [0.000347977]
#     PRN -> , IN DT , [0.00338983]
#     JJ -> 'index-fund' [0.000173989]
#     VP -> VB S PP-MNR [7.10379e-05]
#     VBG -> 'leveraging' [0.000696379]
#     VBG -> 'owning' [0.000696379]
#     NP-SBJ-2 -> RB JJ [0.00315457]
#     VP -> VB S SBAR-ADV [7.10379e-05]
#     SINV -> MD NP-SBJ VP [0.00515464]
#     S -> PP-MNR , NP-SBJ-1 VP . [0.000119374]
#     S-NOM -> NP-SBJ-2 ADVP-TMP VP [0.00323625]
#     JJS -> 'cheapest' [0.0056338]
#     NP -> DT ADJP `` JJ '' NN [4.34934e-05]
#     ADJP -> ADVP RB JJR [0.00150602]
#     NP-SBJ-1 -> RBS JJ NN NNS [0.00100908]
#     JJ -> 'fundamental' [0.000521966]
#     JJ -> 'vast' [0.000173989]
#     JJ -> 'fundamentalist' [0.000347977]
#     VB -> 'contribute' [0.000794123]
#     NN -> 'hysteria' [7.73635e-05]
#     VBG -> 'surrounding' [0.00139276]
#     VBP -> 'pursue' [0.000767165]
#     NNS -> 'opportunities' [0.000336219]
#     VP -> VBP SBAR-PRP [0.000142076]
#     VBP -> 'arise' [0.000767165]
#     VP -> VBG NP PP-LOC-CLR [7.10379e-05]
#     NN -> 'buy' [0.000309454]
#     JJ -> 'cumbersome' [0.000173989]
#     NNS -> 'desires' [0.00016811]
#     JJ -> 'fast' [0.000173989]
#     SBARQ -> RB SBAR-ADV , WHADVP-1 SQ . [0.04]
#     VP -> VBZ ADVP S-NOM-PRD [7.10379e-05]
#     S-NOM-PRD -> NP-SBJ VP [1.0]
#     NNS -> 'inefficiencies' [0.000336219]
#     SQ -> VBD `` NP-SBJ '' VP [0.0294118]
#     VP -> VB PP-CLR ADVP-MNR [7.10379e-05]
#     VB -> 'evolve' [0.000397062]
#     JJ -> 'evil' [0.000521966]
#     NN -> 'creature' [7.73635e-05]
#     VBG -> 'evoking' [0.000696379]
#     NNS -> 'curses' [0.00016811]
#     VBP -> 'conclude' [0.000767165]
#     S -> `` NP-SBJ-1 '' VP [0.000119374]
#     VBN -> 'implemented' [0.000475172]
#     NP -> LST VBN NN [4.34934e-05]
#     NP -> LST DT JJ NN NN [4.34934e-05]
#     NP -> LST NP PP [4.34934e-05]
#     NN -> 'playing' [0.000154727]
#     JJ -> 'unneeded' [0.000173989]
#     JJ -> 'harmful' [0.000173989]
#     VBG -> 'Reducing' [0.000696379]
#     VP -> VBN SBAR-ADV [7.10379e-05]
#     JJ -> 'sufficient' [0.000173989]
#     NN -> 'Arbitrage' [0.000154727]
#     VBZ -> 'responds' [0.000477099]
#     VBZ -> 'causes' [0.000477099]
#     VBG -> 'initiating' [0.000696379]
#     RB -> 'likely' [0.000718133]
#     VP -> VBZ NP PP-DIR PP-DIR , SBAR-ADV [7.10379e-05]
#     VBZ -> 'transfers' [0.000477099]
#     VBG -> 'functioning' [0.000696379]
#     VP -> MD ADVP-MNR VP [0.000142076]
#     RB -> 'fundamentally' [0.000359066]
#     VP -> VB CC VB NP S-PRP [7.10379e-05]
#     VB -> 'decrease' [0.000397062]
#     NN -> 'ownership' [0.000464181]
#     JJ -> 'hypothetical' [0.000173989]
#     VP -> VB PP-LOC ADVP-PRP [7.10379e-05]
#     S -> ADVP NP-SBJ-1 VP . [0.000119374]
#     VP -> VB PP-CLR NP [7.10379e-05]
#     VB -> 'sacrifice' [0.000397062]
#     ADJP -> DT ADJP CC ADJP [0.00150602]
#     FRAG -> FRAG : FRAG . [0.0106383]
#     FRAG -> IN RB NP-LOC , RB PP-LOC [0.0106383]
#     FRAG -> IN RB NP-LOC , RB NP-LOC [0.0106383]
#     NP-LOC -> DT NNP [0.00719424]
#     NP-LOC -> RB [0.00719424]
#     VP -> VBZ UCP-PRP [7.10379e-05]
#     UCP-PRP -> RB PP , CC SBAR [1.0]
#     PP -> IN IN NP [0.000601926]
#     NP-SBJ -> PRP$ [0.000269942]
#     NN -> 'subtraction' [7.73635e-05]
#     JJ -> 'finite' [0.000173989]
#     NN -> 'liquidity' [0.000464181]
#     VB -> 'Eliminate' [0.000397062]
#     VP -> VB PP , S-ADV [7.10379e-05]
#     VP -> VBZ RB S-PRD , SBAR-PRP [7.10379e-05]
#     S-PRD -> NP-SBJ-79 VP [0.0454545]
#     NP-SBJ-79 -> -NONE- [0.5]
#     VP -> VBN NP ADVP [0.000213114]
#     VBN -> 'feared' [0.000475172]
#     NP-SBJ -> ADJP NN [0.000134971]
#     JJR -> 'cleaner' [0.00536913]
#     ADJP-PRD -> JJ , RB JJ [0.00170648]
#     JJ -> 'loathsome' [0.000173989]
#     VP -> VBG NP PRT [7.10379e-05]
#     NNS -> 'tablets' [0.00016811]
#     VBG -> 'Encouraging' [0.000696379]
#     NN -> 'investing' [7.73635e-05]
#     JJ -> 'cautious' [0.000347977]
#     VBG -> 'labeling' [0.000696379]
#     ADJP -> `` JJ '' CC `` JJ [0.00150602]
#     NNS -> 'Policies' [0.00016811]
#     JJ -> 'akin' [0.000173989]
#     VP -> VBG NP PP-CLR VP-1 [7.10379e-05]
#     VP-1 -> VBG : `` S [0.142857]
#     NNS -> 'Buyers' [0.00016811]
#     ADJP-PRD -> VB [0.00170648]
#     S -> NP-VOC INTJ NP-SBJ VP [0.000119374]
#     NP-VOC -> NNS [0.5]
#     INTJ -> VB [0.3]
#     VB -> 'please' [0.000397062]
#     JJ -> 'ultimate' [0.000521966]
#     VB -> 'concern' [0.000397062]
#     SBAR-NOM -> IN S [0.0377358]
#     RB -> 'sufficiently' [0.000359066]
#     VB -> 'tolerate' [0.000794123]
#     NP-SBJ -> NP SBAR-ADV [0.000134971]
#     JJ -> 'annualized' [0.000173989]
#     NN -> 'deviation' [7.73635e-05]
#     VP -> VBZ ADJP-PRD NP-TMP [0.000213114]
#     NNS -> 'Periods' [0.00016811]
#     NN -> 'advent' [7.73635e-05]
#     NP -> NNS CC NN NN [0.00013048]
#     VP -> VBD ADVP-TMP ADJP-PRD , ADVP-TMP SBAR-TMP PRN [7.10379e-05]
#     VBG -> 'undergoing' [0.000696379]
#     PRN -> -LRB- NP PP -RRB- [0.00338983]
#     CD -> '1973-75' [0.000286738]
#     CD -> '1937-40' [0.000286738]
#     CD -> '1928-33' [0.000286738]
#     VP -> VBZ ADJP-PRD S-2 [7.10379e-05]
#     NP-SBJ-3 -> DT JJ NN NNS [0.00980392]
#     VP -> VB `` NP '' PP-CLR SBAR-TMP , SBAR-ADV [7.10379e-05]
#     VB -> 'scream' [0.000397062]
#     VBG -> 'hailing' [0.000696379]
#     VP -> ADVP-TMP VBG SBAR-ADV [7.10379e-05]
#     VBG -> 'abounding' [0.000696379]
#     SQ -> MD NP-SBJ ADVP VP . [0.0294118]
#     MD -> 'Could' [0.00109111]
#     ADVP-PRD -> VBN PP [0.0294118]
#     NNS -> 'deeds' [0.00016811]
#     NNS -> 'goblins' [0.00016811]
#     NNS -> 'fixes' [0.00016811]
#     S -> NP-SBJ-80 VP [0.000119374]
#     NP-SBJ-80 -> -NONE- [0.5]
#     JJ -> 'whipping' [0.000173989]
#     NN -> 'boy' [7.73635e-05]
#     VBG -> 'wooing' [0.000696379]
#     NP -> PRP$ VBG JJ NNS [4.34934e-05]
#     JJ -> 'stock-selection' [0.000173989]
#     VP -> MD , ADVP , VP [7.10379e-05]
#     VP -> VB S NP-ADV [7.10379e-05]
#     VBG -> 'bringing' [0.000696379]
#     JJ -> 'damaging' [0.000173989]
#     PP -> IN PP-LOC [0.000200642]
#     NP-SBJ -> NP PRN PP [0.000134971]
#     PRN -> , INTJ NP , [0.00338983]
#     VB -> 'sound' [0.000397062]
#     NP-SBJ-1 -> DT [0.00201816]
#     VP -> VB ADJP-CLR [7.10379e-05]
#     ADJP-CLR -> JJ SBAR [0.5]
#     VP -> VBP DT VP [7.10379e-05]
#     VBG -> 'Getting' [0.000696379]
#     VP -> VBZ ADVP NP-PRD : PP-PRP [7.10379e-05]
#     NP -> DT ADJP CD [4.34934e-05]
#     VBG -> 'abolishing' [0.000696379]
#     PP-PRP -> RB PP , CC PP [0.0125]
#     NNS -> 'merits' [0.00016811]
#     VBG -> 'championing' [0.000696379]
#     JJS -> 'loudest' [0.0056338]
#     VBP -> 'cater' [0.000767165]
#     VP -> VBP NP PP-CLR , SBAR-ADV [7.10379e-05]
#     VBP -> 'advise' [0.000767165]
#     WHNP-1 -> WDT JJ NNS [0.0030303]
#     NP-SBJ-2 -> PRP$ NNS [0.00315457]
#     VB -> 'hope' [0.000397062]
#     NNS -> 'commissions' [0.000504329]
#     NN -> 'index-fund' [7.73635e-05]
#     VBP -> 'amass' [0.000767165]
#     RB -> 'somehow' [0.000359066]
#     JJ -> 'noble' [0.000173989]
#     NN -> 'expert' [0.000270772]
#     RB -> 'studiously' [0.000359066]
#     VBG -> 'devouring' [0.000696379]
#     NNS -> 'clippings' [0.00016811]
#     NP-SBJ-81 -> RB DT JJ NN [0.5]
#     RB -> 'Almost' [0.000359066]
#     NN -> 'guy' [7.73635e-05]
#     RB -> 'invariably' [0.000359066]
#     ADJP -> JJS JJ S [0.00150602]
#     S -> SBAR-ADV , ADVP NP-SBJ VP . [0.000119374]
#     NNS -> 'spreads' [0.00016811]
#     RB -> 'surely' [0.000718133]
#     NN -> 'mutual-fund' [7.73635e-05]
#     JJ -> 'sad' [0.000173989]
#     VP -> VBZ S SBAR-ADV [7.10379e-05]
#     VP -> VB NP ADVP-TMP , SBAR-ADV-3 [7.10379e-05]
#     JJ -> 'stellar' [0.000347977]
#     NNS -> 'performers' [0.00016811]
#     SBAR-ADV-3 -> IN S [0.5]
#     VB -> 'grapple' [0.000397062]
#     SBAR-ADV -> -NONE- [0.00346021]
#     -NONE- -> '*PPA*-3' [0.000462285]
#     JJ -> 'Cost-effective' [0.000173989]
#     ADJP -> JJ RB [0.00150602]
#     JJ -> 'sexy' [0.000173989]
#     NP -> DT JJ NNS CC NNS [8.69868e-05]
#     NN -> 'roadblock' [7.73635e-05]
#     S -> NP-SBJ-82 VP [0.000119374]
#     NP-SBJ-82 -> -NONE- [1.0]
#     -NONE- -> '*-82' [0.000154095]
#     VP -> VB NP ADVP-MNR , ADVP-LOC [7.10379e-05]
#     JJ -> 'high-volume' [0.000173989]
#     ADVP-LOC -> RB CC RB [0.0119048]
#     S -> S-NOM-SBJ VP . [0.000358123]
#     VBG -> 'Legislating' [0.000696379]
#     ADJP-PRD -> JJR PP [0.00170648]
#     JJR -> 'harder' [0.0107383]
#     SBARQ -> RB WHNP-78 SQ . [0.04]
#     VBN -> 'Left' [0.000475172]
#     VP -> VB ADJP-PRD , S-ADV [7.10379e-05]
#     ADVP -> RBR CC RBR [0.00108814]
#     ADJP-PRD -> JJR CC JJR SBAR [0.00170648]
#     RB -> 'profitably' [0.000718133]
#     NNS -> 'Spreads' [0.00016811]
#     RB -> 'tight' [0.000359066]
#     VB -> 'matter' [0.000397062]
#     WHNP-79 -> WDT NN [0.5]
#     VP -> VB NP-1 PP [0.000142076]
#     JJ -> 'temporary' [0.000173989]
#     NP-SBJ -> UCP NNS [0.000134971]
#     NNS -> 'watchdogs' [0.00016811]
#     VP -> VBP , ADVP , PP-CLR [7.10379e-05]
#     NN -> 'friction' [7.73635e-05]
#     NP -> NP , NP , NP , NP , FW [4.34934e-05]
#     JJ -> 'two-tiered' [0.000173989]
#     NN -> 'taxation' [7.73635e-05]
#     FW -> 'etc.' [0.25]
#     NN -> 'loser' [7.73635e-05]
#     VBG -> 'inviting' [0.000696379]
#     VP -> VB CC VB NP PP-LOC ADVP-MNR [7.10379e-05]
#     VB -> 'transfer' [0.000397062]
#     VBZ -> 'executes' [0.000477099]
#     VBG -> 'warning' [0.00208914]
#     JJ -> 'antitrust' [0.00226185]
#     NNS -> 'agencies' [0.000672438]
#     JJR -> 'further' [0.00268456]
#     VP -> ADVP VBN ADVP-MNR PP-TMP [7.10379e-05]
#     WHNP-80 -> WDT [0.5]
#     NP-SBJ-83 -> -NONE- [0.5]
#     VB -> 'affect' [0.000397062]
#     VP -> VBD PP NP [7.10379e-05]
#     WHNP-81 -> WDT [0.5]
#     NP-SBJ-3 -> NNS CC NNS [0.00980392]
#     SBAR -> WHADVP-4 S [0.000879121]
#     NNS -> 'filings' [0.00100866]
#     NNS -> 'mergers' [0.000504329]
#     S -> NP-SBJ ADVP-MNR VP . [0.000119374]
#     NP -> RB NNPS [4.34934e-05]
#     NNP -> 'Brooks' [0.000107788]
#     VBP -> 'fear' [0.000767165]
#     NNS -> 'cuts' [0.000672438]
#     NP-SBJ -> NNP NNP CC NNP NNS [0.000134971]
#     NNP -> 'FTC' [0.000538938]
#     VB -> 'operate' [0.00158825]
#     VB -> 'augment' [0.000397062]
#     NNP -> 'Rill' [0.000107788]
#     S -> PP-LOC , NP-SBJ-84 VP . [0.000119374]
#     NP-SBJ-84 -> NP PP [0.5]
#     NNP -> 'Antitrust' [0.000107788]
#     NNP -> 'Division' [0.000107788]
#     VP -> VBN NP NP-ADV [7.10379e-05]
#     VBN -> 'cut' [0.00142552]
#     S -> NP-SBJ-85 VP . [0.000119374]
#     NP-SBJ-85 -> NP PP , SBAR , [0.5]
#     WHNP-1 -> WHNP WHPP [0.00606061]
#     WHNP -> QP -NONE- [0.0212766]
#     CD -> '34' [0.000573477]
#     NP -> NP PP PP SBAR-ADV [4.34934e-05]
#     VBN -> 'appropriated' [0.000475172]
#     VBG -> 'offsetting' [0.00208914]
#     NNP -> 'Hart-Scott-Rodino' [0.000107788]
#     QP -> CC RBR [0.00130719]
#     VB -> 'notify' [0.000397062]
#     NP -> NNP CC NNP NNP JJ NNS [4.34934e-05]
#     VBG -> 'completing' [0.000696379]
#     NNS -> 'Proponents' [0.00016811]
#     VBP -> 'predict' [0.000767165]
#     PP -> VBN IN NP [0.000200642]
#     VP -> VB NP NP-TMP , CC NP-1 [7.10379e-05]
#     VB -> 'yield' [0.0111177]
#     NP -> ADJP JJR [4.34934e-05]
#     S -> `` S-TPC-2 , NP-SBJ VP . [0.000119374]
#     S-TPC-2 -> SBAR-TMP , S , CC S [0.0119048]
#     NN -> 'cut' [0.00023209]
#     VP -> VBZ PP NP-PRD [7.10379e-05]
#     NP -> NP '' ADVP [4.34934e-05]
#     NNP -> 'Don' [0.000107788]
#     NNP -> 'Edwards' [0.000215575]
#     NP -> NP , NP-LOC . [4.34934e-05]
#     VB -> 'stifle' [0.000397062]
#     S -> NP-SBJ-87 VP [0.000119374]
#     NNS -> 'staffs' [0.00016811]
#     NP -> PDT DT NNP CC NNP NNP [4.34934e-05]
#     PDT -> 'both' [0.037037]
#     VP -> VBN NP NP-EXT PP-TMP [7.10379e-05]
#     VP -> VBD PRT ADVP-MNR PP-TMP [7.10379e-05]
#     RB -> 'drastically' [0.000359066]
#     VP -> VB SBAR ADVP-TMP [7.10379e-05]
#     S -> NP-SBJ PP VP [0.000358123]
#     VBZ -> 'sanctions' [0.000477099]
#     JJ -> 'dismal' [0.000173989]
#     SBAR -> WHPP-3 S [0.00043956]
#     WHPP-3 -> IN WHNP [1.0]
#     NN -> 'excess' [0.000154727]
#     VB -> 'inhibit' [0.000397062]
#     IN -> 'Though' [0.000103204]
#     NNS -> 'acquirers' [0.00016811]
#     VP -> VBP NP-CLR [7.10379e-05]
#     VBN -> 'noticed' [0.000475172]
#     NN -> 'FALL' [7.73635e-05]
#     NN -> 'BALLOT' [7.73635e-05]
#     NNS -> 'ISSUES' [0.00016811]
#     JJ -> 'off-year' [0.000173989]
#     JJ -> 'Odd-year' [0.000173989]
#     NN -> 'ballot' [0.00023209]
#     S-TPC-1 -> CC NP-SBJ , SBAR-ADV , VP [0.00460829]
#     FRAG -> PP [0.0106383]
#     VP -> VBZ `` NP [0.000142076]
#     VBG -> 'ratcheting' [0.000696379]
#     NP -> NN NN CC VBZ [4.34934e-05]
#     NN -> 'referenda' [7.73635e-05]
#     VBZ -> 'initiatives' [0.000477099]
#     NNP -> 'Patrick' [0.000215575]
#     NNP -> 'McGuigan' [0.000215575]
#     NP -> NNP , NNP CC NNP NNP [0.00013048]
#     NNP -> 'Family' [0.000215575]
#     NNP -> 'Democracy' [0.000107788]
#     NP-SBJ -> NP PP-LOC NP-TMP [0.000134971]
#     JJ -> 'citizen-sparked' [0.000173989]
#     NNS -> 'ballots' [0.00016811]
#     JJ -> 'odd-year' [0.000173989]
#     NN -> 'Ballot' [0.000154727]
#     VBP -> 'range' [0.000767165]
#     NNP -> 'Maine' [0.000107788]
#     NN -> 'initiative' [7.73635e-05]
#     NN -> 'Cruise' [7.73635e-05]
#     NNS -> 'missiles' [0.00016811]
#     NNP -> 'Dakota' [0.000107788]
#     SINV -> S-TPC-1 , '' VP NP-SBJ . '' [0.00515464]
#     S-TPC-1 -> PP-LOC , NP-SBJ VP [0.00460829]
#     VBN -> 'finished' [0.000475172]
#     NNP -> 'Schmidt' [0.000107788]
#     NNP -> 'Citizen' [0.000107788]
#     NNPS -> 'Lawmakers' [0.00417537]
#     NNP -> 'Oklahoma' [0.000215575]
#     JJ -> 'Hot' [0.000173989]
#     NP-PRD -> NP , NP CC NP [0.00367647]
#     S-TPC-2 -> S-ADV , NP-SBJ-1 VP [0.0238095]
#     NN -> 'cue' [7.73635e-05]
#     VBG -> 'backing' [0.000696379]
#     NNP -> 'Magleby' [0.000107788]
#     NNP -> 'Brigham' [0.000107788]
#     NN -> 'PHOTOGRAPH' [7.73635e-05]
#     NN -> 'COLLECTING' [7.73635e-05]
#     VBZ -> 'gains' [0.000477099]
#     NN -> 'Price' [7.73635e-05]
#     VP -> NN PP-LOC NP-TMP [7.10379e-05]
#     NNP -> 'Christie' [0.000107788]
#     NN -> 'folio' [7.73635e-05]
#     NNS -> 'prints' [0.000504329]
#     NP -> NP `` NNS '' NN [4.34934e-05]
#     NNP -> 'Stieglitz' [0.000215575]
#     NNS -> 'Equivalents' [0.00016811]
#     CD -> '396,000' [0.000286738]
#     JJ -> 'single-lot' [0.000173989]
#     NNS -> 'variables' [0.00016811]
#     VBN -> 'documented' [0.000475172]
#     JJ -> 'anecdotal' [0.000173989]
#     NNP -> 'Gates-Warren' [0.000107788]
#     NNP -> 'Sotheby' [0.000107788]
#     VP -> VBZ ADVP NP-PRD PP-LOC [7.10379e-05]
#     NP-SBJ -> NNS CC NNS [0.000134971]
#     NNS -> 'museums' [0.00016811]
#     VP -> VBP PP-PRD , S-ADV [7.10379e-05]
#     NN -> 'stability' [0.000154727]
#     NNP -> 'Persky' [0.000107788]
#     NNP -> 'Photograph' [0.000107788]
#     NNP -> 'Collector' [0.000107788]
#     S -> `` SBAR-TMP , NP-SBJ VP . '' [0.000119374]
#     VP -> VBP S ADVP-TMP [7.10379e-05]
#     VP -> VB ADVP PP-LOC [7.10379e-05]
#     FRAG -> PP : NP . [0.0212766]
#     ADVP -> JJS [0.00326442]
#     NNS -> 'masters' [0.00016811]
#     NNP -> 'Ray' [0.000215575]
#     NP-SBJ -> RB JJ NN [0.000134971]
#     VBG -> 'fetching' [0.000696379]
#     NNP -> 'Miles' [0.000107788]
#     NNP -> 'Barth' [0.000107788]
#     NNP -> 'Photography' [0.000107788]
#     VBG -> 'DIALING' [0.000696379]
#     S-ADV -> NP-SBJ ADVP-TMP NP-PRD [0.00465116]
#     ADJP -> $ CD JJ [0.00150602]
#     JJ -> 'million-a-year' [0.000173989]
#     NP-SBJ-1 -> CD NN NN [0.00100908]
#     VP -> IN NP PP-TMP [7.10379e-05]
#     NNP -> 'Joel' [0.000107788]
#     NNP -> 'Gross' [0.000107788]
#     NP-SBJ-1 -> NP : SBAR : [0.00100908]
#     NN -> 'caller' [7.73635e-05]
#     QP -> IN CD NNS TO $ CD [0.00130719]
#     NN -> 'celebrity' [7.73635e-05]
#     NN -> 'chatter' [7.73635e-05]
#     NNS -> 'horoscopes' [0.00016811]
#     NNS -> 'lines' [0.000840548]
#     NP-SBJ -> RBR JJ NNS [0.000134971]
#     SBAR-PRD -> WHADVP-2 S [0.0294118]
#     SINV -> `` S-TPC-2 , '' VP NP-SBJ-3 , S-ADV . [0.00515464]
#     NNP -> 'Andrea' [0.000107788]
#     NP -> NNP NNP CC NNP NNP [0.000173974]
#     NNS -> 'tutorials' [0.00016811]
#     NNS -> 'Colleges' [0.00016811]
#     VBG -> 'eyeing' [0.000696379]
#     NNS -> 'Charities' [0.00016811]
#     VBP -> 'test' [0.000767165]
#     NN -> 'raising' [7.73635e-05]
#     VB -> 'break' [0.00119119]
#     ADVP-CLR -> RB JJ [0.0204082]
#     NN -> 'merchandising' [7.73635e-05]
#     JJ -> 'Much' [0.000173989]
#     VB -> 'migrate' [0.000397062]
#     VBZ -> 'predicts' [0.000477099]
#     NNP -> 'Lawless' [0.000107788]
#     NNP -> 'US' [0.000107788]
#     NNP -> 'Sprint' [0.000107788]
#     NN -> 'FAMILY' [7.73635e-05]
#     NNS -> 'PETS' [0.00016811]
#     NN -> 'recovery' [7.73635e-05]
#     NNS -> 'patients' [0.000336219]
#     NNP -> 'Hospital' [0.000215575]
#     NNP -> 'Milwaukee' [0.000107788]
#     S-TPC-3 -> NP-SBJ-2 VP [0.0454545]
#     NNS -> 'Patients' [0.00016811]
#     JJ -> 'canine' [0.000173989]
#     JJ -> 'feline' [0.000173989]
#     NN -> 'blood' [0.00023209]
#     NN -> 'appetite' [7.73635e-05]
#     JJ -> 'receptive' [0.000173989]
#     NN -> 'therapy' [7.73635e-05]
#     NNP -> "O'Loughlin" [0.000107788]
#     NN -> 'coordinator' [7.73635e-05]
#     SQ -> FRAG [0.0294118]
#     FRAG -> ADJP . [0.0106383]
#     JJ -> 'TIRED' [0.000173989]
#     VBG -> 'TRIMMING' [0.000696379]
#     NP-SBJ -> NNP NNP CC NNP [0.000269942]
#     NNP -> 'Hammacher' [0.000107788]
#     NNP -> 'Schlemmer' [0.000107788]
#     JJ -> 'fiber-optic' [0.000173989]
#     NNP -> 'Christmas' [0.000107788]
#     VB -> 'string' [0.000397062]
#     NP-SBJ-1 -> DT ADJP NN [0.00100908]
#     CD -> '6,500' [0.000286738]
#     NP -> ADJP VBN NN [4.34934e-05]
#     RB -> 'continuously' [0.000359066]
#     VBN -> 'colored' [0.000475172]
#     JJ -> 'fiber-end' [0.000173989]
#     NNS -> 'bunches' [0.00016811]
#     FRAG-HLN -> NP : S . [0.5]
#     NNP -> 'MEDICINE' [0.000107788]
#     NNP -> 'TRANSPLANT' [0.000107788]
#     VBZ -> 'prompts' [0.000477099]
#     NNP -> 'Israel' [0.000323363]
#     JJ -> 'bilingual' [0.000173989]
#     VBN -> 'Funded' [0.000475172]
#     NNP -> 'Tokio' [0.000107788]
#     NNP -> 'Marine' [0.00118566]
#     NNP -> 'Fire' [0.000215575]
#     VB -> 'follow' [0.000794123]
#     NNS -> 'protocols' [0.00016811]
#     JJ -> 'preventative' [0.000173989]
#     NN -> 'DIAPER' [7.73635e-05]
#     NNS -> 'SERVICES' [0.00016811]
#     NN -> 'comeback' [7.73635e-05]
#     NP -> VBG JJ NNS [8.69868e-05]
#     VBN -> 'Concerned' [0.000475172]
#     VBG -> 'shrinking' [0.000696379]
#     NNS -> 'landfills' [0.00016811]
#     JJ -> 'super-absorbent' [0.000173989]
#     NNS -> 'disposables' [0.00016811]
#     NN -> 'cloth' [0.000154727]
#     NN -> 'diaper' [0.000309454]
#     NNP -> 'Tiny' [0.000107788]
#     NNPS -> 'Tots' [0.00417537]
#     VP -> VBZ ADVP-PRD PP-TMP [7.10379e-05]
#     ADVP-PRD -> IN NP [0.0882353]
#     CD -> '1,200' [0.000286738]
#     NNP -> 'Mogavero' [0.000107788]
#     NNP -> 'Piscataway' [0.000107788]
#     NNP -> 'Syracuse' [0.000107788]
#     NP-SBJ -> NP JJ NN NN [0.000269942]
#     NNP -> 'DyDee' [0.000107788]
#     NN -> 'push' [7.73635e-05]
#     VBZ -> 'stresses' [0.000477099]
#     NN -> 'awareness' [7.73635e-05]
#     JJ -> 'day-care' [0.000173989]
#     VBD -> 'spurned' [0.000334672]
#     NP-SBJ -> NP PP , NP-LOC , [0.000269942]
#     NNP -> 'Diaper' [0.000215575]
#     CD -> '672' [0.000286738]
#     NNS -> 'inquiries' [0.00016811]
#     NNP -> 'Elisa' [0.000107788]
#     NNP -> 'Hollis' [0.000107788]
#     VP -> VBD NP NP-TMP SBAR-PRP [7.10379e-05]
#     NP-SBJ -> NP-LOC SBAR , [0.000134971]
#     VP -> VBZ ADVP-LOC-CLR [7.10379e-05]
#     NP-SBJ -> NP NP-TMP [0.000269942]
#     NN -> 'Diaper' [7.73635e-05]
#     NNS -> 'shortages' [0.00016811]
#     VBD -> 'limited' [0.000334672]
#     NP -> NP , NP-LOC SBAR [4.34934e-05]
#     NNP -> 'Stork' [0.000107788]
#     NNP -> 'Springfield' [0.000107788]
#     VP -> VBZ ADVP-PRD PP ADVP-LOC [7.10379e-05]
#     FRAG -> S-ADV : NP . [0.0106383]
#     VBG -> 'spurring' [0.000696379]
#     NN -> 'Velcro' [7.73635e-05]
#     NNS -> 'fasteners' [0.000336219]
#     VBP -> 'eliminate' [0.000767165]
#     NNS -> 'pins' [0.00016811]
#     NP-HLN -> NNPS : [0.027027]
#     NNPS -> 'BRIEFS' [0.00417537]
#     SINV -> S-TPC-1 , VP NP-SBJ : . [0.00515464]
#     CD -> '57.6' [0.000286738]
#     NNPS -> 'Yorkers' [0.00417537]
#     VP -> VBP NP , NP-ADV [7.10379e-05]
#     NP-ADV -> NP PP-LOC [0.00549451]
#     NN -> 'viewership' [7.73635e-05]
#     NNP -> 'Impact' [0.000107788]
#     NNP -> 'Columbus' [0.000107788]
#     NNP -> 'FreudToy' [0.000107788]
#     NN -> 'pillow' [7.73635e-05]
#     VBG -> 'bearing' [0.00139276]
#     NN -> 'likeness' [7.73635e-05]
#     NNP -> 'Sigmund' [0.000107788]
#     NNP -> 'Freud' [0.000107788]
#     VBN -> 'marketed' [0.00142552]
#     CD -> '24.95' [0.000286738]
#     NN -> 'tool' [7.73635e-05]
#     JJ -> 'do-it-yourself' [0.000173989]
#     S-1 -> S PRN `` CC S . '' [0.0119048]
#     NNP -> 'Egnuss' [0.000323363]
#     NP -> DT NAC-LOC , NN CC NNS NNS NN [4.34934e-05]
#     NAC-LOC -> NNP NNP , NNP [0.0357143]
#     NNP -> 'Plains' [0.000107788]
#     PP-PRD -> TO NP [0.0119048]
#     PP-PRD -> IN ADJP [0.0119048]
#     RB -> 'sure' [0.000359066]
#     VBZ -> 'doubts' [0.000477099]
#     NN -> 'dislike' [7.73635e-05]
#     VBN -> 'echoed' [0.000475172]
#     NP -> NNP NNP NNP NNS [4.34934e-05]
#     S -> CC PP , S , CC S . [0.000119374]
#     VBN -> 'halted' [0.000475172]
#     SBAR -> SBAR , SBAR CC SBAR [0.00043956]
#     NN -> 'quantity' [0.000309454]
#     VP -> VB PRT ADVP-TMP SBAR-CLR [7.10379e-05]
#     VB -> 'figure' [0.000794123]
#     ADVP-TMP -> JJR [0.00326797]
#     SBAR-CLR -> WHADVP-1 S [0.142857]
#     VBG -> 'heading' [0.000696379]
#     VBZ -> 'blames' [0.000477099]
#     ADJP-PRD -> VBD [0.00170648]
#     VBD -> 'overvalued' [0.000334672]
#     NN -> 'junk' [0.00216618]
#     NP -> DT NN , SBAR [4.34934e-05]
#     S -> CC , SBAR-ADV : `` NP-SBJ VP . '' [0.000119374]
#     NNP -> 'Arighi' [0.000215575]
#     JJ -> 'interior' [0.000173989]
#     NN -> 'decorator' [7.73635e-05]
#     NNP -> 'Arnold' [0.000215575]
#     VP -> VBP NP NP-TMP [7.10379e-05]
#     VBP -> 'spook' [0.000767165]
#     VBZ -> 'creates' [0.000954198]
#     JJ -> 'deviant' [0.000173989]
#     JJ -> 'sound' [0.000173989]
#     JJ -> 'inherent' [0.000260983]
#     VBG -> 'curbing' [0.000696379]
#     NP-PRD -> DT RB JJ NN [0.00183824]
#     RB -> 'darned' [0.000359066]
#     NP -> DT NNP NNP CC NNP NN [4.34934e-05]
#     NNP -> 'Schwab' [0.000107788]
#     NNP -> 'Buckhead' [0.000107788]
#     VP -> NNS NP [7.10379e-05]
#     NN -> 'skepticism' [7.73635e-05]
#     VBG -> 'Citing' [0.000696379]
#     S -> S : S [0.000119374]
#     VBD -> 'threatened' [0.000334672]
#     NP-SBJ -> NP , NP , '' [0.000134971]
#     NNP -> 'Anderson' [0.000107788]
#     JJ -> '59-year-old' [0.000173989]
#     NP-SBJ -> NP `` NNS CC NNS [0.000134971]
#     NNS -> 'fluctuations' [0.00016811]
#     NNS -> 'heebie-jeebies' [0.00016811]
#     VBG -> 'outlawing' [0.000696379]
#     S -> NP-SBJ `` VP . [0.000119374]
#     VP -> VB PP ADVP-MNR [7.10379e-05]
#     PP -> IN '' NP [0.000200642]
#     S -> ADVP , NP-SBJ-1 VP . '' [0.000119374]
#     NNP -> 'Wamre' [0.000107788]
#     JJ -> '31-year-old' [0.000173989]
#     VB -> 'disappear' [0.000397062]
#     VBG -> 'dealing' [0.000696379]
#     VBZ -> 'decries' [0.000477099]
#     PP-CLR -> IN `` S-NOM [0.00167645]
#     VBG -> 'limiting' [0.00139276]
#     RB -> 'strictly' [0.000359066]
#     VB -> 'denounce' [0.000397062]
#     VBG -> 'denouncing' [0.00139276]
#     NN -> 'capitalism' [7.73635e-05]
#     VBG -> 'adapting' [0.000696379]
#     NP -> JJR NN NN NN [8.69868e-05]
#     NNP -> 'Britta' [0.000107788]
#     NP -> DT JJ NNP NNP JJ NN [4.34934e-05]
#     JJ -> '25-year-old' [0.000173989]
#     VP -> `` VBG '' NP `` PP-CLR [7.10379e-05]
#     VBG -> 'factoring' [0.000696379]
#     VBZ -> 'increases' [0.0014313]
#     PRT -> JJ [0.00458716]
#     JJ -> 'back' [0.000173989]
#     S-2 -> CC NP-SBJ-1 VP . '' [0.025641]
#     VP -> VBN NP PRN SBAR-PRP [7.10379e-05]
#     NP-SBJ -> RB JJ NNS [0.000134971]
#     JJ -> 'immune' [0.000347977]
#     NNS -> 'rigors' [0.00016811]
#     S-ADV -> NP-SBJ ADVP PP-PRD [0.00465116]
# ...
#     PP-PRD -> PP CC PP [0.0119048]
#     NNS -> 'races' [0.00016811]
#     JJ -> 'minority-owned' [0.000173989]
#     JJ -> 'blighted' [0.000173989]
#     VP -> VBN S PP PP-LOC [7.10379e-05]
#     JJ -> 'famous' [0.000173989]
#     NNP -> 'Jimmy' [0.000107788]
#     NNP -> 'Carter' [0.000215575]
#     NP -> PRP$ CD JJ NN [4.34934e-05]
#     VBD -> 'plugged' [0.000334672]
#     PP-DIR -> RB IN NP [0.0025974]
#     VBG -> 'rebuilding' [0.000696379]
#     NP -> DT NN : NNP NNP NN [4.34934e-05]
#     CD -> "'80s" [0.000286738]
#     VBG -> 'Starting' [0.000696379]
#     NNP -> 'Congressman' [0.000107788]
#     NNP -> 'Mario' [0.000107788]
#     NNP -> 'Biaggi' [0.000107788]
#     VP -> ADVP-TMP VBG NP [7.10379e-05]
#     NN -> 'sentence' [7.73635e-05]
#     VBG -> 'bribing' [0.000696379]
#     NP -> UCP JJ NNS [4.34934e-05]
#     UCP -> JJ , NN CC JJ [0.04]
#     ADVP-LOC -> JJ PP [0.0119048]
#     PP -> ADVP PP CC PP NP-2 [0.000200642]
#     NP-2 -> NP , NP [0.0238095]
#     NNP -> 'Wallach' [0.000107788]
#     NP -> JJ NNP NNP NNP NNP [4.34934e-05]
#     NNP -> 'Attorney' [0.000107788]
#     NNP -> 'Meese' [0.000107788]
#     ADJP -> JJ VBN [0.00150602]
#     VBN -> 'fashioned' [0.000475172]
#     NN -> 'bribery' [7.73635e-05]
#     VP -> VBD NP-CLR PP-CLR , S-ADV [7.10379e-05]
#     NP-CLR -> JJ NN [0.037037]
#     NN -> 'peddling' [7.73635e-05]
#     NP -> ADJP `` JJ '' NN NNS [4.34934e-05]
#     RB -> 'politically' [0.000359066]
#     JJ -> 'respectable' [0.000173989]
#     NN -> 'confidant' [7.73635e-05]
#     NNP -> 'Lyn' [0.000107788]
#     NNP -> 'Nofzinger' [0.000107788]
#     VP -> VBD CC VBD NP PP-CLR [7.10379e-05]
#     NP-SBJ -> DT VBN [0.000134971]
#     VBN -> 'bribed' [0.000475172]
#     NN -> 'merit' [7.73635e-05]
#     JJ -> 'corrupt' [0.000173989]
#     NN -> 'scheme' [7.73635e-05]
#     NP -> CONJP NP , CC NP [4.34934e-05]
#     NN -> 'bag' [7.73635e-05]
#     NN -> 'crook' [7.73635e-05]
#     VP -> VBD NP ADVP-LOC-CLR [7.10379e-05]
#     ADVP-LOC-CLR -> IN PP [0.25]
#     NN -> 'cold' [7.73635e-05]
#     VBD -> 'befell' [0.000334672]
#     NP -> NP JJ `` NN '' NN [4.34934e-05]
#     JJ -> 'semiliterate' [0.000173989]
#     S -> CC PP , NP-SBJ ADVP-TMP VP . [0.000119374]
#     JJ -> 'sensational' [0.000173989]
#     NNS -> 'revelations' [0.00016811]
#     NP -> DT JJ , JJ JJ NN NN [4.34934e-05]
#     JJ -> 'breezy' [0.000173989]
#     JJ -> 'easy-to-read' [0.000173989]
#     NN -> 'writing' [7.73635e-05]
#     NP-SBJ -> `` NNP NNP '' [0.000134971]
#     JJ -> 'gripping' [0.000173989]
#     NNS -> 'scams' [0.00016811]
#     NN -> 'ingenuity' [7.73635e-05]
#     NNS -> 'Auditors' [0.00016811]
#     NN -> 'crookery' [7.73635e-05]
#     NP-TMP -> NP PP-LOC [0.00287356]
#     VBD -> 'bribed' [0.000334672]
#     NN -> 'garden-variety' [7.73635e-05]
#     NNS -> 'lifes' [0.00016811]
#     NP -> NNPS NNS [4.34934e-05]
#     NNPS -> 'Mercedes' [0.00417537]
#     NNS -> 'clothes' [0.00016811]
#     NP-SBJ -> RB CD [0.000134971]
#     VP -> VBZ UCP-PRD [7.10379e-05]
#     UCP-PRD -> VP , CC ADJP-PRD [0.166667]
#     VBG -> 'wrestling' [0.000696379]
#     NP -> JJ CC JJ [4.34934e-05]
#     JJ -> 'intelligent' [0.000173989]
#     JJ -> 'insane' [0.000173989]
#     ADVP -> ADVP RB [0.00108814]
#     NNP -> 'Irving' [0.000107788]
#     NNP -> 'Lobsenz' [0.000107788]
#     NN -> 'pediatrician' [7.73635e-05]
#     NNP -> 'Rusty' [0.000107788]
#     NN -> 'gambler' [7.73635e-05]
#     NN -> 'blackjack' [7.73635e-05]
#     VBN -> 'arrested' [0.000475172]
#     VBN -> 'Absorbed' [0.000475172]
#     VBG -> 'doling' [0.000696379]
#     NP -> `` NP '' NNS [4.34934e-05]
#     NNS -> 'tidbits' [0.00016811]
#     VBP -> 'gloss' [0.000767165]
#     NP -> NP PP , ADVP NP [4.34934e-05]
#     NN -> 'root' [7.73635e-05]
#     NP -> DT NN CD -LRB- NN -RRB- JJ NN [4.34934e-05]
#     WHNP -> WP$ NNS [0.0212766]
#     NNS -> 'auspices' [0.00016811]
#     VP -> VBD NP-CLR PP [7.10379e-05]
#     VP -> VB ADVP-CLR PP-CLR [7.10379e-05]
#     JJ -> 'rigid' [0.000173989]
#     JJ -> 'affirmative' [0.000173989]
#     NNS -> 'Programs' [0.00016811]
#     NP -> NN CD -LRB- NN -RRB- [4.34934e-05]
#     PP-PRD -> NP-ADV IN S-NOM [0.0119048]
#     VBG -> 'expressing' [0.000696379]
#     NNS -> 'thieves' [0.00016811]
#     VP -> VBP PRT S-PRP-CLR ADVP-TMP [7.10379e-05]
#     RP -> 'by' [0.004662]
#     VB -> 'scoop' [0.000397062]
#     NP-SBJ -> NP , PP NP , [0.000134971]
#     JJ -> 'Numerous' [0.000173989]
#     NNS -> 'scandals' [0.00016811]
#     NNP -> 'HUD' [0.000107788]
#     NNS -> 'characteristics' [0.00016811]
#     VP -> VBP NP-CLR PP [7.10379e-05]
#     JJ -> 'tailor-made' [0.000173989]
#     SQ -> VBP NP-SBJ-2 RB VP [0.0294118]
#     VP -> VBN NP ADVP-PRP [7.10379e-05]
#     S -> `` NP-SBJ '' VP . [0.000119374]
#     SINV -> PP-LOC-3 VP NP-SBJ . [0.00515464]
#     PP-LOC-3 -> IN CC IN NP [1.0]
#     VP -> VBN NP-4 PP-CLR [7.10379e-05]
#     NN -> 'insider' [7.73635e-05]
#     WRB -> 'whenever' [0.00568182]
#     VP -> VP , VP CC VP ADVP-TMP [7.10379e-05]
#     VBG -> 'redistributing' [0.000696379]
#     VP -> VBG , VBG CC VBG NP [7.10379e-05]
#     VBG -> 'influencing' [0.000696379]
#     VBG -> 'brokering' [0.000696379]
#     NN -> 'bloc' [7.73635e-05]
#     NN -> 'Nomenklatura' [7.73635e-05]
#     NP -> RB DT NN S [4.34934e-05]
#     WHNP-1 -> WRB JJ NN NNS CC NNS [0.0030303]
#     VBP -> 'exist' [0.000767165]
#     VBP -> 'line' [0.000767165]
#     NNP -> 'Stern' [0.000107788]
#     VP -> VBD NP-PRD , NP-TMP [7.10379e-05]
#     NP -> NN CC NN JJ NN [4.34934e-05]
#     NP -> DT NNP NNP NNP NNP NNP NNP [4.34934e-05]
#     NNP -> 'Urban' [0.000107788]
#     CD -> '1983-85' [0.000286738]
#     NP -> JJ NN NNP NNP NNPS NNP [4.34934e-05]
#     JJ -> 'bankrupt' [0.000173989]
#     NNP -> 'Oy' [0.000323363]
#     VP -> VBD PP-MNR S [7.10379e-05]
#     VB -> 'form' [0.000397062]
#     S -> S-2 , NP-SBJ VP . [0.000119374]
#     NN -> 'Everything' [7.73635e-05]
#     NNP -> 'Christian' [0.000107788]
#     NNP -> 'Andersson' [0.000107788]
#     VBN -> 'finalized' [0.000475172]
#     VP -> VB NP PP-CLR SBAR-PRP-3 [7.10379e-05]
#     JJ -> 'state-appointed' [0.000173989]
#     NNS -> 'receivers' [0.00016811]
#     SBAR-PRP-3 -> WHADVP-2 S [0.5]
#     VP -> VB CC VB NP ADVP [7.10379e-05]
#     VB -> 'lease' [0.000397062]
#     S-TPC-3 -> S CC S [0.0454545]
#     NNS -> 'Subcontractors' [0.00016811]
#     NN -> 'swift' [7.73635e-05]
#     VB -> 'avert' [0.000397062]
#     JJ -> 'skilled' [0.000173989]
#     NP -> NP CD JJ NNS [4.34934e-05]
#     NNS -> 'shipyards' [0.00016811]
#     VP -> VB NP-PRD , S-ADV [7.10379e-05]
#     VBG -> 'injecting' [0.000696379]
#     NN -> 'markkaa' [0.00023209]
#     NNS -> 'Customers' [0.00016811]
#     JJ -> 'undelivered' [0.000173989]
#     VB -> 'subscribe' [0.000397062]
#     NP -> DT VBG QP NN [4.34934e-05]
#     CD -> '170' [0.000286738]
#     NP-SBJ -> NP JJS NN [0.000134971]
#     NP-PRD -> JJ NNP NNP NNPS NNP [0.00183824]
#     NNPS -> 'Lines' [0.00417537]
#     VBD -> 'presented' [0.000334672]
#     NP -> QP -NONE- NNS [4.34934e-05]
#     NNP -> 'Helsinki' [0.000107788]
#     NP-SBJ-2 -> PRP$ NNS S [0.00315457]
#     VBN -> 'dashed' [0.000475172]
#     NP -> PRP$ UCP NNS [4.34934e-05]
#     UCP -> JJ CC NN NN [0.04]
#     S-TPC-3 -> PP , NP-SBJ-2 VP [0.0454545]
#     VB -> 'repay' [0.000397062]
#     NNP -> 'Nichol' [0.000323363]
#     NNP -> 'Karns' [0.000215575]
#     VBD -> 'attempted' [0.000334672]
#     JJ -> 'Concurrent' [0.000173989]
#     NP -> PRP$ NN NNS NNS [4.34934e-05]
#     NP -> ADJP NNP NNP NNP [4.34934e-05]
#     NNP -> 'Norfolk' [0.000107788]
#     VBD -> 'sputtered' [0.000334672]
#     VP -> ADVP VBD NP-TMP [7.10379e-05]
#     VBD -> 'collapsed' [0.000334672]
#     NNP -> 'Ralston' [0.000646726]
#     NNP -> 'Purina' [0.000107788]
#     NP -> DT ADJP NN NN NN [4.34934e-05]
#     NN -> 'pet' [0.00023209]
#     CD -> '45.2' [0.000286738]
#     CD -> '84.9' [0.000286738]
#     CD -> '1.24' [0.000286738]
#     CD -> '422.5' [0.000286738]
#     CD -> '6.44' [0.000286738]
#     CD -> '387.8' [0.000286738]
#     CD -> '5.63' [0.000286738]
#     CD -> '70.2' [0.000286738]
#     NN -> 'seafood' [7.73635e-05]
#     CD -> '5.8' [0.000286738]
#     NN -> 'phase-out' [7.73635e-05]
#     NN -> 'battery' [0.00023209]
#     NNP -> 'Hostess' [0.000107788]
#     NN -> 'cake' [0.000154727]
#     NN -> 'bakery' [7.73635e-05]
#     S-TPC-3 -> NP-SBJ-1 VP [0.0454545]
#     NP -> JJ NN NN CC NN NN NNS [4.34934e-05]
#     JJ -> 'rechargeable' [0.000173989]
#     NN -> 'cadmium' [7.73635e-05]
#     NN -> 'carbon' [7.73635e-05]
#     NN -> 'zinc' [7.73635e-05]
#     NNS -> 'ingredients' [0.00016811]
#     VBD -> 'required' [0.000334672]
#     NN -> 'cereal' [7.73635e-05]
#     NP -> JJR VBG NN [4.34934e-05]
#     NP-ADV -> JJR [0.00549451]
#     NNP -> 'Continental' [0.000107788]
#     NNP -> 'Baking' [0.000107788]
#     NN -> 'bread' [7.73635e-05]
#     NP-SBJ-1 -> PRP$ NNP NN NN [0.00100908]
#     NNP -> 'Eveready' [0.000107788]
#     VP -> VBD NP-TMP PP-CLR , ADVP-CLR , PP-LOC [7.10379e-05]
#     CD -> '80.50' [0.000286738]
#     NNS -> 'Companies' [8.40548e-05]
#     JJ -> 'five-cent' [8.69943e-05]
#     VBN -> 'omitted' [0.000237586]
#     NN -> 'percent' [3.86817e-05]
#     RB -> 'Otherwise' [0.000179533]
#     JJ -> '300-day' [8.69943e-05]
#     CD -> '55.1' [0.000143369]
#     JJ -> 'cash-and-stock' [8.69943e-05]
#     NNP -> 'Ravenswood' [5.38938e-05]
#     JJ -> 'corn-buying' [8.69943e-05]
#     NN -> 'binge' [3.86817e-05]
#     NNS -> 'bottlenecks' [8.40548e-05]
#     NN -> 'pipeline' [3.86817e-05]
#     NNS -> 'exporters' [0.000420274]
#     NN -> 'river' [0.000116045]
#     NNS -> 'barges' [0.000252164]
#     NNS -> 'trains' [8.40548e-05]
#     VBN -> 'harvested' [0.000237586]
#     NNS -> 'ports' [0.00016811]
#     VBG -> 'loading' [0.000348189]
#     NN -> 'River' [3.86817e-05]
#     NN -> 'barge' [0.000116045]
#     NN -> 'Railroad' [3.86817e-05]
#     VBG -> 'reaping' [0.000348189]
#     NN -> 'windfall' [3.86817e-05]
#     VB -> 'gyrate' [0.000198531]
#     VBP -> 'scrounge' [0.000383583]
#     NN -> 'strain' [3.86817e-05]
#     NNP -> 'Mississippi' [0.000323363]
#     VBG -> 'shipping' [0.000696379]
#     NNP -> 'Dunton' [5.38938e-05]
#     RB -> 'real' [0.000179533]
#     NNS -> 'Plains' [8.40548e-05]
#     JJ -> 'upper' [8.69943e-05]
#     VBG -> 'trimming' [0.000348189]
#     NNS -> 'tows' [8.40548e-05]
#     VBP -> 'push' [0.000383583]
#     RB -> 'south' [0.000179533]
#     NNP -> 'Corps' [0.000215575]
#     NNPS -> 'Engineers' [0.00417537]
#     NNP -> 'Missouri' [0.000161681]
#     VBZ -> 'feeds' [0.00023855]
#     NNS -> 'reservoirs' [8.40548e-05]
#     NN -> 'Barge' [3.86817e-05]
#     VBD -> 'sank' [0.000167336]
#     VB -> 'alleviate' [0.000198531]
#     VBN -> 'slowed' [0.000237586]
#     JJ -> 'Similar' [8.69943e-05]
#     VBP -> 'hamstrung' [0.000383583]
#     VBG -> 'budding' [0.000348189]
#     JJ -> 'logistical' [8.69943e-05]
#     VB -> 'calculate' [0.000198531]
#     NN -> 'bushel' [0.000154727]
#     CD -> '2.375' [0.000143369]
#     NN -> 'Corn' [3.86817e-05]
#     NN -> 'harvest' [0.000154727]
#     VB -> 'rebuild' [0.000198531]
#     NNS -> 'stockpiles' [0.000252164]
#     VBN -> 'depleted' [0.000237586]
#     VBG -> 'winding' [0.000348189]
#     VBG -> 'speculating' [0.000348189]
#     VBP -> 'try' [0.000383583]
#     VB -> 'gather' [0.000198531]
#     VBN -> 'obligated' [0.000237586]
#     NN -> 'storage' [7.73635e-05]
#     VBZ -> 'permits' [0.00023855]
#     CD -> '2.15' [0.000143369]
#     NNP -> 'Lyle' [5.38938e-05]
#     NNP -> 'Railroad' [5.38938e-05]
#     NNP -> 'Waterloo' [5.38938e-05]
#     VBZ -> 'projects' [0.00023855]
#     NN -> 'one-fifth' [3.86817e-05]
#     NNP -> 'Biedermann' [5.38938e-05]
#     NNP -> 'Allendale' [5.38938e-05]
#     VB -> 'sidestep' [0.000198531]
#     NN -> 'train' [3.86817e-05]
#     NN -> 'port' [3.86817e-05]
#     NNS -> 'Ports' [8.40548e-05]
#     NNPS -> 'Lakes' [0.00208768]
#     NNP -> 'Coast' [5.38938e-05]
#     VB -> 'relieve' [0.000198531]
#     VBG -> 'hauling' [0.000348189]
#     VBN -> 'compressed' [0.000237586]
#     VBN -> 'delayed' [0.000237586]
#     NN -> 'ENERGY' [3.86817e-05]
#     NN -> 'refinery' [3.86817e-05]
#     VBG -> 'tightening' [0.000348189]
#     NN -> 'Heating' [3.86817e-05]
#     CD -> '58.64' [0.000143369]
#     CD -> '19.94' [0.000143369]
#     NN -> 'sell-off' [3.86817e-05]
#     NNP -> 'PRECIOUS' [5.38938e-05]
#     NNPS -> 'METALS' [0.00208768]
#     CD -> '3.20' [0.000143369]
#     CD -> '377.60' [0.000143369]
#     NN -> 'silver' [3.86817e-05]
#     CD -> '6.50' [0.000143369]
#     CD -> '5.2180' [0.000143369]
#     NN -> 'platinum' [7.73635e-05]
#     CD -> '5.70' [0.000143369]
#     CD -> '494.50' [0.000143369]
#     JJ -> 'Precious' [8.69943e-05]
#     VBN -> 'influenced' [0.000237586]
#     NNP -> "O'Neill" [5.38938e-05]
#     NNPS -> 'Elders' [0.00208768]
#     NNS -> 'equities' [8.40548e-05]
#     NN -> 'Silver' [7.73635e-05]
#     NNS -> 'warehouses' [8.40548e-05]
#     CD -> '170,262' [0.000143369]
#     CD -> '226,570,380' [0.000143369]
#     NNS -> 'miners' [8.40548e-05]
#     VB -> 'strike' [0.000397062]
#     CD -> '1.20' [0.000143369]
#     CD -> '1.14' [0.000143369]
#     NNP -> 'Bronces' [5.38938e-05]
#     NNP -> 'Soldado' [5.38938e-05]
#     JJ -> 'Exxon-owned' [8.69943e-05]
#     NNP -> 'Minera' [5.38938e-05]
#     NNP -> 'Disputada' [5.38938e-05]
#     NNS -> 'Reasons' [8.40548e-05]
#     NN -> 'walkout' [3.86817e-05]
#     JJ -> 'procedural' [8.69943e-05]
#     NN -> 'metal' [0.000116045]
#     JJ -> 'upbeat' [8.69943e-05]
#     NN -> 'mood' [3.86817e-05]
#     VBN -> 'reflected' [0.000237586]
#     VBZ -> 'precedes' [0.00023855]
#     CD -> '51.6' [0.000143369]
#     NNS -> 'readings' [8.40548e-05]
#     CD -> '47.1' [0.000143369]
#     VBZ -> 'points' [0.00023855]
#     NNP -> 'NCR' [5.38938e-05]
#     NNP -> 'Tower' [0.000107788]
#     JJ -> 'midrange' [8.69943e-05]
#     VBN -> 'advanced' [0.000237586]
#     NN -> 'networking' [3.86817e-05]
#     NN -> 'hub' [3.86817e-05]
#     NNP -> 'Novell' [5.38938e-05]
#     NNP -> 'NetWare' [5.38938e-05]
#     JJ -> 'like' [8.69943e-05]
#     VBG -> 'riding' [0.000348189]
#     JJ -> 'industrywide' [8.69943e-05]
#     NNS -> 'chunks' [8.40548e-05]
#     NNP -> 'Marcus' [5.38938e-05]
#     NN -> 'appliance' [3.86817e-05]
#     VBP -> 'hurt' [0.000383583]
#     NNS -> 'steelmakers' [0.000252164]
#     NNP -> 'Lorain' [5.38938e-05]
#     CD -> '50-50' [0.000143369]
#     NN -> 'joint' [3.86817e-05]
#     NNP -> 'Kobe' [5.38938e-05]
#     VBG -> 'earning' [0.000348189]
#     NNP -> 'Bethlehem' [5.38938e-05]
#     CD -> '54' [0.000143369]
#     NNP -> 'Inland' [5.38938e-05]
#     VBD -> 'plummeted' [0.000167336]
#     CD -> '34.625' [0.000143369]
#     VBD -> 'exceeded' [0.000167336]
#     NNS -> 'projections' [8.40548e-05]
#     NNP -> 'Bradford' [5.38938e-05]
#     JJR -> 'richer' [0.00134228]
#     NN -> 'pipe' [3.86817e-05]
#     JJ -> 'galvanized' [8.69943e-05]
#     VBN -> 'coated' [0.000237586]
#     JJ -> 'lower-priced' [8.69943e-05]
#     JJ -> 'structural' [8.69943e-05]
#     NNP -> 'Marathon' [5.38938e-05]
#     CD -> '198' [0.000143369]
#     NN -> 'red' [3.86817e-05]
#     VBG -> 'soliciting' [0.000348189]
#     NNP -> 'TXO' [5.38938e-05]
#     NNS -> 'Proceeds' [8.40548e-05]
#     CD -> '15.5' [0.000143369]
#     CD -> '257' [0.000143369]
#     NNP -> 'Icahn' [0.000107788]
#     CD -> '13.1' [0.000143369]
#     CD -> '721' [0.000143369]
#     CD -> '2.62' [0.000143369]
#     CD -> '598' [0.000143369]
#     CD -> '2.07' [0.000143369]
#     NNP -> 'Barrett' [5.38938e-05]
#     NNP -> 'Leon' [5.38938e-05]
#     NNP -> 'Level' [5.38938e-05]
#     NNP -> 'McFarlan' [5.38938e-05]
#     NNP -> 'DiLoreto' [5.38938e-05]
#     NN -> 'container' [3.86817e-05]
#     NNP -> 'Delmont' [5.38938e-05]
#     NN -> 'constitutional-law' [3.86817e-05]
#     NNP -> 'Professors' [5.38938e-05]
#     NNP -> 'Kurland' [0.000107788]
#     NNP -> 'Laurence' [5.38938e-05]
#     NNP -> 'Tribe' [0.000107788]
#     VB -> 'claim' [0.000397062]
#     NN -> 'procedure' [7.73635e-05]
#     VB -> 'scuttle' [0.000198531]
#     RB -> 'implicitly' [0.000179533]
#     NNP -> 'Kennedy' [0.000107788]
#     NNS -> 'professors' [0.00016811]
#     NNS -> 'ends' [8.40548e-05]
#     NN -> 'spectrum' [3.86817e-05]
#     NN -> 'liberal' [3.86817e-05]
#     VBZ -> 'authorizes' [0.00023855]
#     JJ -> 'partial' [8.69943e-05]
#     VBD -> 'covered' [0.000167336]
#     NNP -> 'Civil' [5.38938e-05]
#     VBN -> 'shared' [0.000237586]
#     JJ -> 'lawmaking' [8.69943e-05]
#     VBZ -> 'supports' [0.00023855]
#     JJ -> 'reckless' [8.69943e-05]
#     NNP -> 'Trinity' [0.000107788]
#     NN -> 'railcar' [3.86817e-05]
#     NNS -> 'platforms' [8.40548e-05]
#     NNP -> 'Trailer' [5.38938e-05]
#     NNP -> 'Train' [5.38938e-05]

# %% [markdown]
# **2. Evaluate the performance of the grammars on the test set (the 3% of the sentences from the treebank that you isolated in the beginning of the exercise). What proportion of sentences from the test set have been parsed as in the reference (i.e. are correctly parsed) by the extracted grammar?**

# %%
# From the created gramar, you create a parser to annotate new sentences
print("Initializing parser")
parser = nltk.ViterbiParser(tbank_grammar) # http://www.nltk.org/_modules/nltk/parse/viterbi.html


# Test the extracted grammar with the Viterbi parser on one sentence.
# The Viterbi parser gives the most probable parse tree
# Test all sentences in the test-set and compare them to the reference parsing

parse_success = 0;
# for i in range(0, len(raw_test_set)):
for i in range(0, 3):
    print("==== Parsing sentence " + str(i))
    test_sent = raw_test_set[i]
    # This will raise an exception if the tokens in the test_sentence
    # are not covered by the grammar; should not happen.
    tbank_grammar.check_coverage(test_sent)
    print(test_sent)
    print("[" + str(i) + "] Reference parse:")
    print(test_set[i])
    print("[" + str(i) + "] Parse trees:")
    for tree in parser.parse(test_sent):
        print(tree)
        print(test_sent[i] == tree)
        if test_sent[i] == tree:
            ++parse_success
        print(parse_success)

print("Successfully parsed sentences: " + str(parse_success) + " out of " + str(3))
#print("Successfully parsed sentences: " + str(parse_success) + " out of " + str(len(test_set)))
# Out:
# Initializing parser
# ==== Parsing sentence 0
# ['Companies', 'listed', '*', 'below', 'reported', 'quarterly', 'profit', 'substantially', 'different', 'from', 'the', 'average', 'of', 'analysts', "'", 'estimates', '.']
# [0] Reference parse:
# (S
#   (NP-SBJ
#     (NP (NNS Companies))
#     (VP (VBN listed) (NP (-NONE- *)) (ADVP-LOC (IN below))))
#   (VP
#     (VBD reported)
#     (NP
#       (NP (JJ quarterly) (NN profit))
#       (ADJP
#         (RB substantially)
#         (JJ different)
#         (PP
#           (IN from)
#           (NP
#             (NP (DT the) (NN average))
#             (PP
#               (IN of)
#               (NP (NP (NNS analysts) (POS ')) (NNS estimates))))))))
#   (. .))
# [0] Parse trees:
# (S
#   (NP-SBJ (NNS Companies))
#   (VP
#     (VBN listed)
#     (NP
#       (NP (-NONE- *))
#       (PP
#         (IN below)
#         (NP (VBN reported) (JJ quarterly) (NN profit))))
#     (ADVP-PRP
#       (RB substantially)
#       (JJ different)
#       (PP
#         (IN from)
#         (NP
#           (DT the)
#           (ADJP
#             (JJ average)
#             (PP (IN of) (NP (NNS analysts) (POS '))))
#           (NNS estimates)))))
#   (. .)) (p=1.834e-56)
# False
# 0
# ==== Parsing sentence 1
# ['The', 'companies', 'are', 'followed', '*-1', 'by', 'at', 'least', 'three', 'analysts', ',', 'and', 'had', 'a', 'minimum', 'five-cent', 'change', 'in', 'actual', 'earnings', 'per', 'share', '.']
# [1] Reference parse:
# (S
#   (NP-SBJ-1 (DT The) (NNS companies))
#   (VP
#     (VP
#       (VBP are)
#       (VP
#         (VBN followed)
#         (NP (-NONE- *-1))
#         (PP
#           (IN by)
#           (NP-LGS
#             (ADVP (IN at) (JJS least))
#             (CD three)
#             (NNS analysts)))))
#     (, ,)
#     (CC and)
#     (VP
#       (VBD had)
#       (NP
#         (NP (DT a) (JJ minimum) (JJ five-cent) (NN change))
#         (PP
#           (IN in)
#           (NP
#             (NP (JJ actual) (NNS earnings))
#             (PP (IN per) (NP (NN share))))))))
#   (. .))
# [1] Parse trees:
# (S
#   (NP-SBJ (DT The) (NNS companies))
#   (VP
#     (VBP are)
#     (VP
#       (VP
#         (VBN followed)
#         (NP (-NONE- *-1))
#         (PP
#           (IN by)
#           (NP
#             (QP (IN at) (JJS least) (CD three))
#             (NNS analysts))))
#       (, ,)
#       (CC and)
#       (VP
#         (VBD had)
#         (NP
#           (NP
#             (DT a)
#             (JJ minimum)
#             (JJ five-cent)
#             (NN change))
#           (PP (IN in) (NP (JJ actual) (NNS earnings))))
#         (PP-CLR (IN per) (NP (NN share))))))
#   (. .)) (p=1.34423e-62)
# False
# 0
# ==== Parsing sentence 2
# ['Estimated', 'and', 'actual', 'results', 'involving', 'losses', 'are', 'omitted', '*-1', '.']
# [2] Reference parse:
# (S
#   (NP-SBJ-1
#     (NP (ADJP (VBN Estimated) (CC and) (JJ actual)) (NNS results))
#     (VP (VBG involving) (NP (NNS losses))))
#   (VP (VBP are) (VP (VBN omitted) (NP (-NONE- *-1))))
#   (. .))
# [2] Parse trees:
# (S
#   (NP-SBJ
#     (NP (VBN Estimated) (JJ and) (JJ actual) (NNS results))
#     (VBG involving)
#     (NNS losses))
#   (VP (VBP are) (VP (VBD omitted) (NP (-NONE- *-1))))
#   (. .)) (p=6.65657e-36)
# False
# 0
# Successfully parsed sentences: 0 out of 3

# %% [markdown]
# **3. We now want to study the size of the grammar with respect to the size of the learning set. Split the former learning set (i.e. the 95%  of the treebank) into two parts: one kept for actual learning and another part which is not used. Do this for several percentages of the learning set (10%, 50%, 70%, 80%, 90%, 100%), several times for each ratio. H ave a look at the resulting grammars and try to understand their differences.**

# %% [markdown]
# ### Useful NLTK commands
#
# Grammar creation from a given string:
#
#     g = nltk.CFG.fromstring("""<grammar rules here>""")
#
# Tokenize a sentence:
#
#     tokens = nltk.word_tokenize("<sentence>")
#
# Create different types of parsers starting from a grammar:
#
#     chart_parser   = nltk.ChartParser(g)
#     viterbi_parser = nltk.ViterbiParser(g)
#
# Parse a tokenized text:
#
#     trees = viterbi_parser.parse(tokens) #for example, for the Viterbi parser
#
# Display the parse trees:
#
# [ If not done yet, you first need to install this library:
# http://tkinter.unpythonic.net/wiki/How_to_install_Tkinter
# ]
#
# The command below will generate a popup window, containing the graphical representation of the tree; while the parse tree drawing window is open, your script will be paused. The script will be resumed when you close the window.
#
#     from nltk.tree import *
#     from nltk.draw import tree
#     tree.draw()

# %% [markdown]
# # Additional Materials: Practical Parsing

# %% [markdown]
# NLTK provides us an excellent way to create our own grammars and train them based on an annotated dataset.
#
# Nevertheless, as happens with Tagging, most of the time the pre-train modules are enough to solve most of our situation.
#
# My recommendation is to use either [`spacy`](https://spacy.io/) or [`Stanford CoreNLP`](https://stanfordnlp.github.io/CoreNLP/) instead of NLTK for that. The parsers of NLTK are slow and outdated, which made them unsuitable for practical situations.
#
# In the following, you have an example of usage of Spacy for dependency parsing, applied to specific tasks

# %% [markdown]
# Firstly, you need to load `spacy` with the desired language, English in this case

# %%
import spacy

# Import the English model
nlp = spacy.load('en_core_web_sm')
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_core_web_sm' (2.2.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# Now we can use the spacy object (`nlp`) to perform the desired language annotations to our sentences

# %%
sent = "I shot an elephant"
doc=nlp(sent)

# %% [markdown]
# The doc object now contains the text plus all the annotations

# %%
print("Tokens:", [t.text for t in doc])
print("Lemmas:", [t.lemma_ for t in doc])
print("POS Tagging:", [t.pos_ for t in doc])
print("Parsing:", [t.dep_ for t in doc])
# Out:
# Tokens: ['I', 'shot', 'an', 'elephant']
# Lemmas: ['-PRON-', 'shoot', 'an', 'elephant']
# POS Tagging: ['PRON', 'VERB', 'DET', 'NOUN']
# Parsing: ['nsubj', 'ROOT', 'det', 'dobj']

# %% [markdown]
# We could use the dependency parsing annotations to identify different parts of the sentences.

# %%
print("Subject:", [tok for tok in doc if (tok.dep_ == "nsubj") ])
print("Verb:", [tok for tok in doc if (tok.dep_ == "ROOT") ])
print("Object:", [tok for tok in doc if ("obj" in tok.dep_ ) ])
# Out:
# Subject: [I]
# Verb: [shot]
# Object: [elephant]

# %% [markdown]
# Let's use it to see what are the objects preferred by Truman in his speech.

# %%
import nltk
from nltk.corpus import state_union
from collections import Counter

nltk.download('state_union')

text = state_union.raw("1946-Truman.txt")

def detect_most_common_objects(corpus_text, n_verbs = 10):
    verbs = []
    for sentence in nltk.sent_tokenize(corpus_text):
        doc = nlp(sentence)
        for tok in doc:
            if ("obj" in tok.dep_):
                verbs.append(tok.lemma_)
    return Counter(verbs).most_common(n_verbs)

detect_most_common_objects(text, 50)
# Out:
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Unzipping corpora/state_union.zip.
# [('year', 188),
#  ('dollar', 156),
#  ('-PRON-', 101),
#  ('program', 80),
#  ('war', 77),
#  ('which', 64),
#  ('expenditure', 50),
#  ('time', 45),
#  ('government', 43),
#  ('Congress', 35),
#  ('production', 35),
#  ('States', 34),
#  ('period', 33),
#  ('level', 32),
#  ('people', 32),
#  ('economy', 31),
#  ('policy', 29),
#  ('Government', 28),
#  ('service', 28),
#  ('legislation', 28),
#  ('country', 26),
#  ('month', 26),
#  ('force', 25),
#  ('world', 25),
#  ('price', 25),
#  ('increase', 24),
#  ('opportunity', 23),
#  ('Administration', 23),
#  ('appropriation', 23),
#  ('control', 22),
#  ('business', 22),
#  ('peace', 22),
#  ('income', 22),
#  ('responsibility', 21),
#  ('purpose', 21),
#  ('June', 21),
#  ('rate', 21),
#  ('power', 20),
#  ('system', 19),
#  ('future', 19),
#  ('end', 19),
#  ('development', 19),
#  ('September', 19),
#  ('Act', 19),
#  ('worker', 19),
#  ('activity', 18),
#  ('objective', 18),
#  ('nation', 18),
#  ('veteran', 18),
#  ('addition', 18)]
